# %% [markdown]
# # PCAP Exploration
# An exploration of pcaps using Workbench https://github.com/SuperCowPowers/workbench.git
# ## Goals of the Exploration
# PCAPS can be opaque, so what do we have, how do we organize it, how do we glean some knowledge?
#
# **Note:** Obviously there are super great tools that already perform exploration and analysis of pcaps: WireShark, Chop Shop, Scapy, blah, foo, etc.. here we leveraging Bro IDS to generate our starting-point data and then hoping off in various directions from there. The work here should be viewed as complimentary to these other tools and you might consider putting into your toolset. :)
#
# ### Start up the workbench server...
# Run the workbench server (from somewhere, for the demo we're just going to start a local one)
# <pre>
# > cd workbench/server
# > python -O workbench.py
# </pre>
#
# #### Okay so when the server starts up, it autoloads any worker plugins in the server/worker directory and dynamically monitors the directory, if a new python file shows up, it's validated as a properly formed plugin and if it passes is added to the list of workers.

# %%
import numpy as np
np.__version__
# Out:
# '1.8.0'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.13.1'

# %%
# Plotting defaults
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 12.0
plt.rcParams['figure.figsize'] = 18.0, 8.0

# %%
# Lets start to interact with workbench, please note there is NO specific client to workbench,
# Just use the ZeroRPC Python, Node.js, or CLI interfaces.
import zerorpc
c = zerorpc.Client(passive_heartbeat=True, timeout=300)
c.connect("tcp://127.0.0.1:4242")
# Out:
# [None]

# %%
# Want to find out about what's on the other side?
print c._zerorpc_name()
print c._zerorpc_list()
# Out:
# workbench
# ['set_datastore_uri', 'have_sample', 'search', 'get_datastore_uri', 'work_request', 'worker_info', 'store_sample', 'get_sample', 'batch_work_request', 'index_worker_output', 'stream_sample', 'els_index_sample']

# %%
# Okay so we see that we're connected to workbench and the calls we can make
# The 'worker_info' call look interesting...
c.worker_info()
# Out:
# {'json_meta': 'This worker computes a meta-data for log files. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'log_meta': 'This worker computes a meta-data for log files. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'meta': 'This worker computes meta-data. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'meta_deep': 'This worker computes deeper meta-data. Output keys: [md5, sha1, sha256, ssdeep, entropy, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'pcap_bro': 'This worker runs Bro scripts on a pcap file. Output keys: [log_name:md5...]',
#  'pcap_meta': 'This worker computes a bunch of meta-data about a pcap file. Output keys: [summary, sessions]',
#  'pe_classifier': 'This worker classifies PEFiles as Evil or Benign. Output keys: [classification]',
#  'pe_features': 'This worker pulls out a bunch of static features from a PEFile. Output keys: [dense_features, sparse_features]',
#  'pe_indicators': 'This worker uses the static features from the pefile module to look for weird stuff.  Output keys: [indicator_list]',
#  'pe_peid': 'This worker using the peid database to look for signatures in a PEFile. Output keys: [match_list]',
#  'strings': 'This worker extracts all the strings from any type of file. Output keys: [string_list]',
#  'unzip': 'This worker unzips a zipped file. Output keys: [payload_md5s]',
#  'urls': 'This worker looks for url patterns in strings output. Output keys: [url_list]',
#  'view': 'This worker generates a view for any type of file. Output keys: [this view calls sub-views, see the concrete class (view_pdf for instance)]',
#  'view_customer': 'This worker generates a customer usage view. Output keys: [filename, md5, length, customer, upload_date]',
#  'view_log_meta': 'This worker generates a view for log meta. Output keys: [mime_type, encoding, import_time, file_size]',
#  'view_meta': 'This worker generates a view for meta about a sample. Output keys: [mime_type, encoding, import_time, ssdeep, entropy, file_size]',
#  'view_pcap_bro': 'This worker generates a pcap view for the sample. Output keys: [bro_output_log_names...]',
#  'view_pcap_meta': 'This worker generates a pcap view for the sample. Output keys: [import_time, entropy, file_size, summary, sessions]',
#  'view_pdf': 'This worker generates a view for a PDF File. Output keys: [filename, filetype, mime_type, encoding, import_time, ssdeep, strings]',
#  'view_pefile': 'This worker generates a view for a PE File. Output keys: [filename, filetype, mime_type, encoding, import_time, ssdeep, indicators, peid_Matches, classification, disass]',
#  'view_zip': 'This worker generates a view for a zip File. Output keys: [filename, filetype, mime_type, payload_md5s, payload_meta]'}

# %% [markdown]
# <div style="float: left; margin: 0px 30px 0px 0px"><img src="files/images/disk.jpg" width="250px"></div>
# # Read in the Data
# <font size=4> Toss a PCAP at workbench, in general there's no constraints on what types of files you can put into workbench. No tools for format XYZ? As a community tool pull requests are encouraged...</font>

# %%
# So we can see all the available workers lets load up a file and run some stuff
# Okay when we load up a file (or pcap in this case), we get the md5 back
filename = '../test_files/pcap/http-disney101.pcap'
with open(filename,'rb') as f:
    md5 = c.store_sample(filename, f.read(), 'pcap')
print md5
# Out:
# 214a3bee34eb952dc49de9d722baf0bb

# %%
# Now lets get the meda data for this pcap
c.work_request('pcap_meta', md5)
# Out:
# {'pcap_meta': {'encoding': 'binary',
#   'file_size': 6364504,
#   'file_type': 'pcap-ng capture file - version 1.0',
#   'filename': '../test_files/pcap/http-disney101.pcap',
#   'import_time': '2014-03-13T20:41:01.881000Z',
#   'md5': '214a3bee34eb952dc49de9d722baf0bb',
#   'mime_type': 'binary',
#   'type_tag': 'pcap'}}

# %%
# Now lets run Bro on this pcap
results = c.work_request('pcap_bro', md5)

# %%
# Critical Code: Transition from Bro log to Pandas Dataframe

# Results is just a dictionary of Bro log file names and their MD5s in workbench
# Take the outputs from workbench and toss them into a set of dataframes
dataframes = {}
for log_name, md5 in results['pcap_bro'].iteritems():

    # Every workbench entry contains an md5 field (obviously not interested in that)
    if log_name == 'md5': continue
        
    bro_log_data = c.stream_sample(md5, None)               # Super magic
    dataframes[log_name] = pd.DataFrame(bro_log_data) # Also super magic

# %% [markdown]
# <div style="float: left; margin: 0px 30px 0px 0px"><img src="files/images/eyeball_2.jpg" width="250px"></div>
# # Lets look at the Data
# We're going to use some nice functionality in the Pandas dataframe to look at our processed data:
#
#     - We can use groupby on the dataframe to see the different header request keys for various agents
#     - Transform the complicated user-agent string into something more managable (short-agent)
#     - Generate a 'feature vector' from the header keys

# %%
# We're going to pick one of the dataframe to explore in more detail
df = dataframes['bro_log_http']
df.head()
# Out:
#   filename                 host     id.orig_h  id.orig_p        id.resp_h  \
# 0        -       www.disney.com  24.6.173.220      35518  199.181.132.249
# 1        -           disney.com  24.6.173.220      35520  199.181.132.249
# 2        -  cdnvideo.dolimg.com  24.6.173.220      35532    208.111.148.6
# 3        -  cdnvideo.dolimg.com  24.6.173.220      35533    208.111.148.6
# 4        -  cdnvideo.dolimg.com  24.6.173.220      35529    208.111.148.6
#
#    id.resp_p info_code info_msg method orig_fuids orig_mime_types password  \
# 0         80         -        -    GET          -               -        -
# 1         80         -        -    GET          -               -        -
# 2         80         -        -    GET          -               -        -
# 3         80         -        -    GET          -               -        -
# 4         80         -        -    GET          -               -        -
#
#   proxied            referrer  request_body_len          resp_fuids  \
# 0       -                   -                 0  Fqf0912AD1COUHCvV6
# 1       -                   -                 0  FOxEG61l1HUGZ2i82j
# 2       -  http://disney.com/                 0  FkI5ha2decrXDTgEyh
# 3       -  http://disney.com/                 0  Fcy7by3fGkXlZRakTi
# 4       -  http://disney.com/                 0  FHxDHx1XzpRITS8Vbj
#
#   resp_mime_types  response_body_len  status_code         status_msg
# 0       text/html                184          301  Moved Permanently ...
# 1       text/html              84912          200                 OK ...
# 2      image/jpeg              28244          200                 OK ...
# 3      image/jpeg              37292          200                 OK ...
# 4      image/jpeg              67349          200                 OK ...
#
# [5 rows x 27 columns]

# %%
# List ALL the columns names for this dataframe
df.columns
# Out:
# Index([u'filename', u'host', u'id.orig_h', u'id.orig_p', u'id.resp_h', u'id.resp_p', u'info_code', u'info_msg', u'method', u'orig_fuids', u'orig_mime_types', u'password', u'proxied', u'referrer', u'request_body_len', u'resp_fuids', u'resp_mime_types', u'response_body_len', u'status_code', u'status_msg', u'tags', u'trans_depth', u'ts', u'uid', u'uri', u'user_agent', u'username'], dtype='object')

# %%
# Convert the 'ts' field to an official datetime object
df['time'] = pd.to_datetime(df['ts'],unit='s')
df['time'].head()
# Out:
# 0   2012-10-24 22:01:30.679418
# 1   2012-10-24 22:01:33.120084
# 2   2012-10-24 22:01:33.221714
# 3   2012-10-24 22:01:33.229326
# 4   2012-10-24 22:01:33.221239
# Name: time, dtype: datetime64[ns]

# %%
# Remove columns that don't have any 'meaningful' values in them
df.replace('-', np.nan, inplace=True)
df.dropna(axis=1, how='all', inplace=True)
df.head()
# Out:
#                   host     id.orig_h  id.orig_p        id.resp_h  id.resp_p  \
# 0       www.disney.com  24.6.173.220      35518  199.181.132.249         80
# 1           disney.com  24.6.173.220      35520  199.181.132.249         80
# 2  cdnvideo.dolimg.com  24.6.173.220      35532    208.111.148.6         80
# 3  cdnvideo.dolimg.com  24.6.173.220      35533    208.111.148.6         80
# 4  cdnvideo.dolimg.com  24.6.173.220      35529    208.111.148.6         80
#
#   method            referrer  request_body_len          resp_fuids  \
# 0    GET                 NaN                 0  Fqf0912AD1COUHCvV6
# 1    GET                 NaN                 0  FOxEG61l1HUGZ2i82j
# 2    GET  http://disney.com/                 0  FkI5ha2decrXDTgEyh
# 3    GET  http://disney.com/                 0  Fcy7by3fGkXlZRakTi
# 4    GET  http://disney.com/                 0  FHxDHx1XzpRITS8Vbj
#
#   resp_mime_types  response_body_len  status_code         status_msg     tags  \
# 0       text/html                184          301  Moved Permanently  (empty)
# 1       text/html              84912          200                 OK  (empty)
# 2      image/jpeg              28244          200                 OK  (empty)
# 3      image/jpeg              37292          200                 OK  (empty)
# 4      image/jpeg              67349          200                 OK  (empty)
#
#    trans_depth            ts                 uid  \
# 0            1  1.351116e+09   CuWFegFswHIMv3ebg
# 1            1  1.351116e+09  CTUAqc2K3iod0KiZnj
# 2            1  1.351116e+09   CBzd1f3oLPAN79gih
# 3            1  1.351116e+09  C80TD03iChkYBIm6Gd
# 4            1  1.351116e+09  CcZe9D2CHk2EC3YWuf
#
#                                                  uri  \
# 0                                                  /
# 1                                                  /
# 2  /cdn_assets/cbb81d69317f2a1c1b5f4d375b71997ea8...
# 3  /cdn_assets/525d4cdb4a32ae2cf6b4b220195893749c...
# 4  /cdn_assets/9d31accc4393a7912869c8d837e51aba20...
#
#                                           user_agent  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:16.0) G...
# 1  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:16.0) G...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:16.0) G...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:16.0) G...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:16.0) G...
#
#                         time
# 0 2012-10-24 22:01:30.679418
# 1 2012-10-24 22:01:33.120084
# 2 2012-10-24 22:01:33.221714
# 3 2012-10-24 22:01:33.229326
# 4 2012-10-24 22:01:33.221239
#
# [5 rows x 20 columns]

# %%
# Dataframe has a nice quick descriptive statistics method
df.describe()
# Out:
#           id.orig_p  id.resp_p  request_body_len  response_body_len  \
# count    103.000000        103               103         103.000000
# mean   35531.718447         80                 0       61245.766990
# std        7.560757          0                 0       55753.773351
# min    35518.000000         80                 0           0.000000
# 25%    35528.000000         80                 0       25234.500000
# 50%    35531.000000         80                 0       51061.000000
# 75%    35533.000000         80                 0       86941.000000
# max    35562.000000         80                 0      354379.000000
#
#        status_code  trans_depth            ts
# count   103.000000   103.000000  1.030000e+02
# mean    202.087379     5.116505  1.351116e+09
# std      14.082465     3.934017  2.534778e+01
# min     200.000000     1.000000  1.351116e+09
# 25%     200.000000     1.000000  1.351116e+09
# 50%     200.000000     4.000000  1.351116e+09
# 75%     200.000000     8.000000  1.351116e+09
# max     302.000000    15.000000  1.351116e+09
#
# [8 rows x 7 columns]

# %%
# Describe gives us a sense for the numeric fields for the
# categorical fields we can use value counts so we're just
# going to loop over all the columns
def gist(df):
    for column in df.columns:
        print '\n<<< %s >>>' % column
        print df[column].value_counts().head()

    
# The output below is verbose but don't under estimate the power of the 'gist' both
# for understanding of the data and quickly uncovering bugs in the reader/data collection.
gist(df)
# Out:
# <<< host >>>
# cdnvideo.dolimg.com    72
# a.dilcdn.com           18
# aglobal.go.com          2
# w88.go.com              2
# pix04.revsci.net        1
# dtype: int64
#
# <<< id.orig_h >>>
# 24.6.173.220    103
# dtype: int64
#
# <<< id.orig_p >>>
# 35533    15
# 35532    13
# 35529    13
# 35530    11
# 35531    11
# dtype: int64
#
# <<< id.resp_h >>>
# 208.111.148.6      74
# 198.78.220.87      18
# 199.181.132.249     2
# 74.217.240.83       2
# 66.235.138.59       2
# dtype: int64
#
# <<< id.resp_p >>>
# 80    103
# dtype: int64
#
# <<< method >>>
# GET    103
# dtype: int64
#
# <<< referrer >>>
# http://disney.com/                                    98
# http://a.dilcdn.com/a/application-8d98127cd6fd.css     2
# dtype: int64
#
# <<< request_body_len >>>
# 0    103
# dtype: int64
#
# <<< resp_fuids >>>
# FbLZ7V29577HaZgFnj    2
# F8LudZ1C8ImghOw5l9    1
# FTLSub3r2Uv2VcYKX3    1
# FUgB862nySBpuGBtt9    1
# FbUwpK24ZiW5Aajvnk    1
# dtype: int64
#
# <<< resp_mime_types >>>
# image/jpeg    71
# text/plain    16
# image/png      5
# binary         3
# text/html      3
# dtype: int64
#
# <<< response_body_len >>>
# 1150      1
# 40782     1
# 167484    1
# 68928     1
# 67        1
# dtype: int64
#
# <<< status_code >>>
# 200    99
# 206     2
# 302     1
# 301     1
# dtype: int64
#
# <<< status_msg >>>
# OK                   99
# Partial Content       2
# Found                 1
# Moved Permanently     1
# dtype: int64
#
# <<< tags >>>
# (empty)    103
# dtype: int64
#
# <<< trans_depth >>>
# 1    27
# 2    11
# 3     9
# 4     8
# 9     6
# dtype: int64
#
# <<< ts >>>
# 1.351116e+09    1
# 1.351116e+09    1
# 1.351116e+09    1
# 1.351116e+09    1
# 1.351116e+09    1
# dtype: int64
#
# <<< uid >>>
# C80TD03iChkYBIm6Gd    15
# CcZe9D2CHk2EC3YWuf    13
# CBzd1f3oLPAN79gih     13
# CRwhwPeAkLrpxHTU1     11
# CSvIxmqOZdpjg7RRb     11
# dtype: int64
#
# <<< uri >>>
# /a/m4-64b108659f6f.woff                                     3
# /                                                           2
# /cdn_assets/f646b72e9c6c1602241ed6ddbfbf224b1cfccb25.jpg    1
# /cdn_assets/124c948f21fc8c3b26de6c0703c112186c7cb648.jpg    1
# /cdn_assets/ceff250ab4b78c3e99ea297c30c229ebcec8de2e.jpg    1
# dtype: int64
#
# <<< user_agent >>>
# Mozilla/5.0 (Windows NT 6.1; WOW64; rv:16.0) Gecko/20100101 Firefox/16.0    103
# dtype: int64
#
# <<< time >>>
# 2012-10-24 22:01:35.951621    1
# 2012-10-24 22:01:33.298988    1
# 2012-10-24 22:01:35.346621    1
# 2012-10-24 22:01:33.465886    1
# 2012-10-24 22:01:35.381118    1
# dtype: int64

# %%
# Explore pivoting and resampling
response_bytes = df[['time','resp_mime_types','response_body_len']]
response_bytes['response_body_len'] = response_bytes['response_body_len'].astype(int)
print response_bytes.head()
pivot = pd.pivot_table(response_bytes, rows='time', values='response_body_len', cols=['resp_mime_types'], aggfunc=sum)
sampled_bytes = pivot.resample('1S', how='sum')
sampled_bytes.head()
# Out:
#                         time resp_mime_types  response_body_len
# 0 2012-10-24 22:01:30.679418       text/html                184
# 1 2012-10-24 22:01:33.120084       text/html              84912
# 2 2012-10-24 22:01:33.221714      image/jpeg              28244
# 3 2012-10-24 22:01:33.229326      image/jpeg              37292
# 4 2012-10-24 22:01:33.221239      image/jpeg              67349
#
# [5 rows x 3 columns]
# resp_mime_types      binary  image/gif  image/jpeg  image/png  image/x-icon  \
# time
# 2012-10-24 22:01:30     NaN        NaN         NaN        NaN           NaN
# 2012-10-24 22:01:31     NaN        NaN         NaN        NaN           NaN
# 2012-10-24 22:01:32     NaN        NaN         NaN        NaN           NaN
# 2012-10-24 22:01:33     NaN       3208     2652246       7825           NaN
# 2012-10-24 22:01:34     NaN        NaN      337783        NaN           NaN
#
# resp_mime_types      text/html  text/plain
# time
# 2012-10-24 22:01:30        184         NaN
# 2012-10-24 22:01:31        NaN         NaN
# 2012-10-24 22:01:32        NaN         NaN
# 2012-10-24 22:01:33      84912      727998
# 2012-10-24 22:01:34        NaN         NaN
#
# [5 rows x 7 columns]

# %%
response_bytes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 3 columns):
# time                 103 non-null datetime64[ns]
# resp_mime_types      102 non-null object
# response_body_len    103 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)

# %%
sampled_bytes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7 entries, 2012-10-24 22:01:30 to 2012-10-24 22:01:36
# Freq: S
# Data columns (total 7 columns):
# binary          1 non-null float64
# image/gif       2 non-null float64
# image/jpeg      4 non-null float64
# image/png       3 non-null float64
# image/x-icon    1 non-null float64
# text/html       3 non-null float64
# text/plain      2 non-null float64
# dtypes: float64(7)

# %%
# Let plot it!
sampled_bytes.plot()

# %%
# Although the plot below looks 'nicer' we have to be SUPER careful with interplolation 
# of any kind as it can often misrepresent the actual data.
interp = sampled_bytes.interpolate(method='linear')
interp.plot()

# %%
sampled_bytes_min = pivot.resample('.1s', how='sum')
sampled_bytes_min.plot()

# %%
interp_min = sampled_bytes_min.interpolate(method='linear')
interp_min.plot()

# %% [markdown]
# <div style="float: left; margin: 0px 30px 0px 0px"><img src="files/images/processing_data.jpg" width="250px"></div>
# # Process the Data
# We're going to use some nice functionality in the Pandas dataframe to process our data:
#
#     - We have both client and server events, just keep the client events for this exercise
#     - Transform the complicated user-agent string into something more managable (short-agent)
#     - Generate a 'feature vector' from the header keys
