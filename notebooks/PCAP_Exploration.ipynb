# %% [markdown]
# # PCAP Exploration
# An exploration of pcaps using Workbench https://github.com/SuperCowPowers/workbench.git
# ## Goals of the Exploration
# PCAPS can be opaque, so what do we have, how do we organize it, how do we glean some knowledge?
#
# **Note:** Obviously there are super great tools that already perform exploration and analysis of pcaps: WireShark, Chop Shop, Scapy, blah, foo, etc.. here we leveraging Bro IDS to generate our starting-point data and then hoping off in various directions from there. The work here should be viewed as complimentary to these other tools and you might consider putting into your toolset. :)
#
# ### Start up the workbench server...
# Run the workbench server (from somewhere, for the demo we're just going to start a local one)
# <pre>
# > cd workbench/server
# > python -O workbench.py
# </pre>
#
# #### Okay so when the server starts up, it autoloads any worker plugins in the server/worker directory and dynamically monitors the directory, if a new python file shows up, it's validated as a properly formed plugin and if it passes is added to the list of workers.

# %%
import numpy as np
np.__version__
# Out:
# '1.8.0'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.13.1'

# %%
# Plotting defaults
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 12.0
plt.rcParams['figure.figsize'] = 18.0, 8.0

# %%
# Lets start to interact with workbench, please note there is NO specific client to workbench,
# Just use the ZeroRPC Python, Node.js, or CLI interfaces.
import zerorpc
c = zerorpc.Client(passive_heartbeat=True, timeout=300)
c.connect("tcp://127.0.0.1:4242")
# Out:
# [None]

# %%
# Want to find out about what's on the other side?
print c._zerorpc_name()
print c._zerorpc_list()
# Out:
# workbench
# ['add_node', 'index_worker_output', 'stream_sample_set', 'add_rel', 'set_datastore_uri', 'work_request', 'has_sample', 'get_sample', 'store_sample', 'stream_sample', 'has_node', 'store_sample_set', 'index_sample', 'search', 'get_datastore_uri', 'worker_info', 'get_sample_set', 'batch_work_request']

# %%
# Okay so we see that we're connected to workbench and the calls we can make
# The 'worker_info' call look interesting...
c.worker_info()
# Out:
# {'json_meta': 'This worker computes a meta-data for log files. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'log_meta': 'This worker computes a meta-data for log files. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'meta': 'This worker computes meta-data. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'meta_deep': 'This worker computes deeper meta-data. Output keys: [md5, sha1, sha256, ssdeep, entropy, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'pcap_bro': 'This worker runs Bro scripts on a pcap file. Output keys: [log_name:md5...]',
#  'pcap_graph': 'This worker generates a graph from a PCAP. Output keys: [...]',
#  'pcap_meta': 'This worker computes a bunch of meta-data about a pcap file. Output keys: [summary, sessions]',
#  'pcap_set_bro': 'This worker runs Bro scripts on a set of pcap files. Output keys: [log_name:md5...]',
#  'pe_classifier': 'This worker classifies PEFiles as Evil or Benign. Output keys: [classification]',
#  'pe_deep_sim': 'This worker computes fuzzy matches between samples with ssdeep. Output keys: [md5, sim_list]',
#  'pe_features': 'This worker pulls out a bunch of static features from a PEFile. Output keys: [dense_features, sparse_features]',
#  'pe_indicators': 'This worker uses the static features from the pefile module to look for weird stuff.  Output keys: [indicator_list]',
#  'pe_peid': 'This worker using the peid database to look for signatures in a PEFile. Output keys: [match_list]',
#  'strings': 'This worker extracts all the strings from any type of file. Output keys: [string_list]',
#  'swf_meta': 'This worker computes a bunch of meta-data about a pcap file. Output keys: [summary, sessions]',
#  'unzip': 'This worker unzips a zipped file. Output keys: [payload_md5s]',
#  'urls': 'This worker looks for url patterns in strings output. Output keys: [url_list]',
#  'view': 'This worker generates a view for any type of file. Output keys: [this view calls sub-views, see the concrete class (view_pdf for instance)]',
#  'view_customer': 'This worker generates a customer usage view. Output keys: [filename, md5, length, customer, upload_date]',
#  'view_log_meta': 'This worker generates a view for log meta. Output keys: [mime_type, encoding, import_time, file_size]',
#  'view_meta': 'This worker generates a view for meta about a sample. Output keys: [mime_type, encoding, import_time, ssdeep, entropy, file_size]',
#  'view_pcap': 'This worker generates a pcap view. Output keys: [bro_logs, extracted_files, ...]',
#  'view_pcap_details': 'This worker generates a detailed pcap view. Output keys: [...]',
#  'view_pcap_meta': 'This worker generates a pcap view for the sample. Output keys: [import_time, entropy, file_size, summary, sessions]',
#  'view_pdf': 'This worker generates a view for a PDF File. Output keys: [filename, filetype, mime_type, encoding, import_time, ssdeep, strings]',
#  'view_pefile': 'This worker generates a view for a PE File. Output keys: [filename, filetype, mime_type, encoding, import_time, ssdeep, indicators, peid_Matches, classification, disass]',
#  'view_zip': 'This worker generates a view for a zip File. Output keys: [filename, filetype, mime_type, payload_md5s, payload_meta]',
#  'vt_query': 'This worker query Virus Total, an apikey needs to be provided. Output keys: [positives, total, scan_date]',
#  'yara_sigs': 'hi'}

# %% [markdown]
# <div style="float: left; margin: 0px 30px 0px 0px"><img src="files/images/disk.jpg" width="250px"></div>
# # Read in the Data
# <font size=4> Toss a PCAP at workbench, in general there's no constraints on what types of files you can put into workbench. No tools for format XYZ? As a community tool pull requests are encouraged...</font>

# %%
# So we can see all the available workers lets load up a file and run some stuff
# Okay when we load up a file (or pcap in this case), we get the md5 back
filename = '../data/pcap/kitchen_boss.pcap'
with open(filename,'rb') as f:
    md5 = c.store_sample(filename, f.read(), 'pcap')
print md5
# Out:
# df4f4a2e2bf020be50a12554942edb88

# %%
# Run the Bro Network Security Monitor on the PCAP (or set of PCAPS) we just loaded.
# We could run several requests here... 'pcap_bro','view_pcap' or 'view_pcap_details',
# workbench is super granular and it's easy to try them all and add your own as well
output = c.work_request('view_pcap_details', md5)['view_pcap_details']
output
# Out:
# {'bro_logs': {'conn_log': 'bd20b5e153d44bf43f95838540230200',
#   'dhcp_log': '55e8aead94d8edf48e636e39c65e846e',
#   'dns_log': '14873855a02c7e3952bf75cc2cf74d20',
#   'files_log': 'a3e84dcbfecb881ad81123fe109bf9e8',
#   'http_log': 'e58c1abb0182e9c48c4e5e37e68fa875',
#   'packet_filter_log': 'c89d73c9ff2a12b66cdf74007af8a952',
#   'weird_log': 'e872ecdb518caf4dcddc1044b90962c5'},
#  'connectionId': 130,
#  'err': None,
#  'extracted_files': [{'entropy': 7.889679107924797,
#    'file_size': 18643,
#    'file_type': 'Java Jar file data (zip)',
#    'md5': 'c762b6ba4f560692b6b84ac212cd3ec2',
#    'sha256': 'c776c5f3b979233c8466fc521e38271bbd59081538e126273fe1a75a228bd25d',
#    'ssdeep': '384:7SXliKrIvBZFzoceSZNZ2wLk588eHYBAXGIsMeV:AiKrKySZNxg5892SGII'},
#   {'entropy': 7.515107193655836,
#    'file_size': 273920,
#    'file_type': 'PE32 executable (GUI) Intel 80386, for MS Windows',
#    'md5': '4410133f571476f2e76e29e61767b557',
#    'sha256': 'e4bbdc8f869502183293797f51d6d64cc6c49d39b82effbcb738abe511054b51',
#    'ssdeep': '6144:RSxqC+ayi6eWLj622ARbJFMQzynbJDxL3oPlRa:oxqC+ayi6p6EmQz+bf3otA'},
#   {'entropy': 7.889679107924797,
#    'file_size': 18643,
#    'file_type': 'Java Jar file data (zip)',
#    'md5': 'c762b6ba4f560692b6b84ac212cd3ec2',
#    'sha256': 'c776c5f3b979233c8466fc521e38271bbd59081538e126273fe1a75a228bd25d',
#    'ssdeep': '384:7SXliKrIvBZFzoceSZNZ2wLk588eHYBAXGIsMeV:AiKrKySZNxg5892SGII'},
#   {'entropy': 7.9751436379093406,
#    'file_size': 7724,
#    'file_type': 'Macromedia Flash data (compressed), version 9',
#    'md5': '16cf037b8c8caad6759afc8c309de0f9',
#    'sha256': '8af130ffe1140894895225e265d5d9a753ad9d85883db742c88f13bae01e2c30',
#    'ssdeep': '192:v27CdZAdM5nmNvipKRRkLozlrEKcgTtpEV3+5jxChbNT3:v27QZAAVpKRRkLu/cOEa9ORD'},
#   {'entropy': 7.9751436379093406,
#    'file_size': 7724,
#    'file_type': 'Macromedia Flash data (compressed), version 9',
#    'md5': '16cf037b8c8caad6759afc8c309de0f9',
#    'sha256': '8af130ffe1140894895225e265d5d9a753ad9d85883db742c88f13bae01e2c30',
#    'ssdeep': '192:v27CdZAdM5nmNvipKRRkLozlrEKcgTtpEV3+5jxChbNT3:v27QZAAVpKRRkLu/cOEa9ORD'},
#   {'entropy': 7.889679107924797,
#    'file_size': 18643,
#    'file_type': 'Java Jar file data (zip)',
#    'md5': 'c762b6ba4f560692b6b84ac212cd3ec2',
#    'sha256': 'c776c5f3b979233c8466fc521e38271bbd59081538e126273fe1a75a228bd25d',
#    'ssdeep': '384:7SXliKrIvBZFzoceSZNZ2wLk588eHYBAXGIsMeV:AiKrKySZNxg5892SGII'},
#   {'entropy': 7.889679107924797,
#    'file_size': 18643,
#    'file_type': 'Java Jar file data (zip)',
#    'md5': 'c762b6ba4f560692b6b84ac212cd3ec2',
#    'sha256': 'c776c5f3b979233c8466fc521e38271bbd59081538e126273fe1a75a228bd25d',
#    'ssdeep': '384:7SXliKrIvBZFzoceSZNZ2wLk588eHYBAXGIsMeV:AiKrKySZNxg5892SGII'},
#   {'entropy': 7.889679107924797,
#    'file_size': 18643,
#    'file_type': 'Java Jar file data (zip)',
#    'md5': 'c762b6ba4f560692b6b84ac212cd3ec2',
#    'sha256': 'c776c5f3b979233c8466fc521e38271bbd59081538e126273fe1a75a228bd25d',
#    'ssdeep': '384:7SXliKrIvBZFzoceSZNZ2wLk588eHYBAXGIsMeV:AiKrKySZNxg5892SGII'},
#   {'entropy': 7.284164074455011,
#    'file_size': 13006,
#    'file_type': 'PDF document, version 1.6',
#    'md5': '40b8c3c98f50e078251ec272620dfb5b',
#    'sha256': '5dac98c66c7440992de9de860dd4312790bcc7bbcbb4aebfdce8b3fdfcfc56af',
#    'ssdeep': '384:jW3+XiQMTXgazaO/J9m1DfN6abiiYEVB0T0DM:Ph+fJSE2r0j'}],
#  'md5': 'df4f4a2e2bf020be50a12554942edb88',
#  'n': 1,
#  'ok': 1.0,
#  'updatedExisting': False}

# %%
# Critical Code: Transition from Bro log to Pandas Dataframe

# Grab the Bro logs that we want
dataframes = {name:pd.DataFrame(c.stream_sample(bro_log, None)) for name, bro_log in output['bro_logs'].iteritems()}

# %%
# Lets see what dataframes we got
dataframes.keys()
# Out:
# ['dns_log',
#  'packet_filter_log',
#  'dhcp_log',
#  'conn_log',
#  'http_log',
#  'weird_log',
#  'files_log']

# %% [markdown]
# <div style="float: left; margin: 0px 30px 0px 0px"><img src="files/images/eyeball_2.jpg" width="250px"></div>
# # Lets look at the Data
# We're going to use some nice functionality in the Pandas dataframe to look at our processed data:
#
#     - We can use groupby on the dataframe to see the different header request keys for various agents
#     - Transform the complicated user-agent string into something more managable (short-agent)
#     - Generate a 'feature vector' from the header keys

# %%
# We're going to pick one of the dataframe to explore in more detail
df = dataframes['http_log']
df.head()
# Out:
#   filename                      host      id.orig_h  id.orig_p  \
# 0        -        kitchenboss.com.au  192.168.22.10       1036
# 1        -    www.kitchenboss.com.au  192.168.22.10       1037
# 2        -    www.kitchenboss.com.au  192.168.22.10       1040
# 3        -       ajax.googleapis.com  192.168.22.10       1048
# 4        -  html5shim.googlecode.com  192.168.22.10       1046
#
#         id.resp_h  id.resp_p info_code info_msg method orig_body_data  \
# 0  111.223.225.83         80         -        -    GET              -
# 1  111.223.225.83         80         -        -    GET              -
# 2  111.223.225.83         80         -        -    GET              -
# 3   74.125.128.95         80         -        -    GET              -
# 4   74.125.128.82         80         -        -    GET              -
#
#   orig_body_length orig_fuids  \
# 0                -          -
# 1                -          -
# 2                -          -
# 3                -          -
# 4                -          -
#
#                                           orig_heads orig_mime_types   params  \
# 0  USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; ...               -  (empty)
# 1  USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; ...               -  (empty)
# 2  ACCEPT:*/*,USER-AGENT:Mozilla/4.0 (compatible;...               -  (empty)
# 3  ACCEPT:*/*,USER-AGENT:Mozilla/4.0 (compatible;...               -  (empty)
# 4  ACCEPT:*/*,HOST:html5shim.googlecode.com,USER-...               -  (empty)
#
#   password proxied                        referrer  request_body_len  \
# 0        -       -                               -                 0
# 1        -       -                               -                 0
# 2        -       -  http://www.kitchenboss.com.au/                 0
# 3        -       -  http://www.kitchenboss.com.au/                 0
# 4        -       -  http://www.kitchenboss.com.au/                 0
#
#   resp_body_length
# 0                - ...
# 1            13944 ...
# 2               98 ...
# 3            10220 ...
# 4             2429 ...
#
# [5 rows x 33 columns]

# %%
# List ALL the columns names for this dataframe
df.columns
# Out:
# Index([u'filename', u'host', u'id.orig_h', u'id.orig_p', u'id.resp_h', u'id.resp_p', u'info_code', u'info_msg', u'method', u'orig_body_data', u'orig_body_length', u'orig_fuids', u'orig_heads', u'orig_mime_types', u'params', u'password', u'proxied', u'referrer', u'request_body_len', u'resp_body_length', u'resp_fuids', u'resp_heads', u'resp_mime_types', u'response_body_len', u'status_code', u'status_msg', u'tags', u'trans_depth', u'ts', u'uid', u'uri', u'user_agent', u'username'], dtype='object')

# %%
# Convert the 'ts' field to an official datetime object
df['time'] = pd.to_datetime(df['ts'],unit='s')
df['time'].head()
# Out:
# 0   2014-04-09 06:38:54.686325
# 1   2014-04-09 06:38:55.549895
# 2   2014-04-09 06:38:56.958887
# 3   2014-04-09 06:38:56.983591
# 4   2014-04-09 06:38:56.983314
# Name: time, dtype: datetime64[ns]

# %%
# Remove columns that don't have any 'meaningful' values in them
df.replace('-', np.nan, inplace=True)
df.dropna(axis=1, how='all', inplace=True)
df.head()
# Out:
#                        host      id.orig_h  id.orig_p       id.resp_h  \
# 0        kitchenboss.com.au  192.168.22.10       1036  111.223.225.83
# 1    www.kitchenboss.com.au  192.168.22.10       1037  111.223.225.83
# 2    www.kitchenboss.com.au  192.168.22.10       1040  111.223.225.83
# 3       ajax.googleapis.com  192.168.22.10       1048   74.125.128.95
# 4  html5shim.googlecode.com  192.168.22.10       1046   74.125.128.82
#
#    id.resp_p method                                         orig_heads  \
# 0         80    GET  USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; ...
# 1         80    GET  USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; ...
# 2         80    GET  ACCEPT:*/*,USER-AGENT:Mozilla/4.0 (compatible;...
# 3         80    GET  ACCEPT:*/*,USER-AGENT:Mozilla/4.0 (compatible;...
# 4         80    GET  ACCEPT:*/*,HOST:html5shim.googlecode.com,USER-...
#
#     params                        referrer  request_body_len  \
# 0  (empty)                             NaN                 0
# 1  (empty)                             NaN                 0
# 2  (empty)  http://www.kitchenboss.com.au/                 0
# 3  (empty)  http://www.kitchenboss.com.au/                 0
# 4  (empty)  http://www.kitchenboss.com.au/                 0
#
#    resp_body_length          resp_fuids  \
# 0               NaN                 NaN
# 1             13944   FL607G2jztRHr8Xbz
# 2                98  FH1gD44gUcIfJgq2J2
# 3             10220   FC8A2X2Jla1xMWhr8
# 4              2429  F3fwSC4WmD0PKQ6HHg
#
#                                           resp_heads resp_mime_types  \
# 0  CONTENT-LENGTH:0,PRAGMA:no-cache,DATE:Wed\x2c ...             NaN
# 1  TRANSFER-ENCODING:chunked,PRAGMA:no-cache,CONT...       text/html
# 2  LAST-MODIFIED:Wed\x2c 15 May 2013 22:53:33 GMT...      text/plain
# 3  EXPIRES:Fri\x2c 03 Apr 2015 02:08:11 GMT,ALTER...      text/plain
# 4  LAST-MODIFIED:Thu\x2c 26 Sep 2013 10:05:49 GMT...       text/html
#
#    response_body_len  status_code         status_msg     tags  trans_depth  \
# 0                  0          301  Moved Permanently  (empty)            1
# 1              13944          200                 OK  (empty)            1
# 2                 98          200                 OK  (empty)            1
# 3              10220          200                 OK  (empty)            1
# 4               2429          200                 OK  (empty)            1
#
#              ts
# 0  1.397026e+09 ...
# 1  1.397026e+09 ...
# 2  1.397026e+09 ...
# 3  1.397026e+09 ...
# 4  1.397026e+09 ...
#
# [5 rows x 24 columns]

# %%
# Dataframe has a nice quick descriptive statistics method
df.describe()
# Out:
#          id.orig_p  id.resp_p  request_body_len  resp_body_length  \
# count    94.000000         94                94         55.000000
# mean   1083.468085         80                 0      29889.072727
# std      27.018792          0                 0      49788.655251
# min    1036.000000         80                 0         35.000000
# 25%    1059.250000         80                 0       1729.500000
# 50%    1083.500000         80                 0      10220.000000
# 75%    1106.750000         80                 0      18643.000000
# max    1129.000000         80                 0     273920.000000
#
#        response_body_len  status_code  trans_depth            ts
# count          94.000000     94.00000    94.000000  9.400000e+01
# mean        17488.287234    240.87234     1.117021  1.397026e+09
# std         40725.515663     51.00395     0.460397  1.877083e+01
# min             0.000000    200.00000     1.000000  1.397026e+09
# 25%             0.000000    200.00000     1.000000  1.397026e+09
# 50%          1013.000000    200.00000     1.000000  1.397026e+09
# 75%         13121.500000    304.00000     1.000000  1.397026e+09
# max        273920.000000    304.00000     4.000000  1.397026e+09
#
# [8 rows x 8 columns]

# %%
# Describe gives us a sense for the numeric fields for the
# categorical fields we can use value counts so we're just
# going to loop over all the columns
def gist(df):
    for column in df.columns:
        print '\n<<< %s >>>' % column
        print df[column].value_counts().head()

    
# The output below is verbose but don't under estimate the power of the 'gist' both
# for understanding of the data and quickly uncovering bugs in the reader/data collection.
gist(df)
# Out:
# <<< host >>>
# www.kitchenboss.com.au          65
# 2496128308-6.focondteavrt.ru     8
# ajax.googleapis.com              4
# www.google-analytics.com         4
# kitchenboss.com.au               4
# dtype: int64
#
# <<< id.orig_h >>>
# 192.168.22.10    94
# dtype: int64
#
# <<< id.orig_p >>>
# 1086    4
# 1083    3
# 1108    2
# 1056    2
# 1070    1
# dtype: int64
#
# <<< id.resp_h >>>
# 111.223.225.83    69
# 142.4.194.92       9
# 74.125.128.95      6
# 74.125.128.100     4
# 173.194.127.11     2
# dtype: int64
#
# <<< id.resp_p >>>
# 80    94
# dtype: int64
#
# <<< method >>>
# GET    94
# dtype: int64
#
# <<< orig_heads >>>
# ACCEPT:*/*,IF-MODIFIED-SINCE:Wed\x2c 15 May 2013 22:53:33 GMT,COOKIE:__utma=96296454.2076123732.1397039937.1397039937.1397039937.1; __utmb=96296454.1.10.1397039937; __utmz=96296454.1397039937.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); PHPSESSID=d454007e1d1a84a0b3e3d890bf6f9109; __utmc=96296454,USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0),REFERER:http://www.kitchenboss.com.au/,CONNECTION:Keep-Alive,ACCEPT-ENCODING:gzip\x2c deflate,HOST:www.kitchenboss.com.au,ACCEPT-LANGUAGE:en-us    23
# ACCEPT:*/*,COOKIE:PHPSESSID=d454007e1d1a84a0b3e3d890bf6f9109; __utma=96296454.2076123732.1397039937.1397039937.1397039937.1; __utmb=96296454.1.10.1397039937; __utmc=96296454; __utmz=96296454.1397039937.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none),USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0),REFERER:http://www.kitchenboss.com.au/,CONNECTION:Keep-Alive,ACCEPT-ENCODING:gzip\x2c deflate,HOST:www.kitchenboss.com.au,ACCEPT-LANGUAGE:en-us    16
# ACCEPT:*/*,USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0),COOKIE:PHPSESSID=d454007e1d1a84a0b3e3d890bf6f9109,REFERER:http://www.kitchenboss.com.au/,CONNECTION:Keep-Alive,ACCEPT-ENCODING:gzip\x2c deflate,HOST:www.kitchenboss.com.au,ACCEPT-LANGUAGE:en-us    13
# ACCEPT-ENCODING:pack200-gzip\x2c gzip,HOST:2496128308-6.focondteavrt.ru,CONTENT-TYPE:application/x-java-archive,USER-AGENT:Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10,ACCEPT:text/html\x2c image/gif\x2c image/jpeg\x2c *; q=.2\x2c */*; q=.2,CONNECTION:keep-alive     4
# ACCEPT:*/*,USER-AGENT:Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0),HOST:www.google-analytics.com,REFERER:http://www.kitchenboss.com.au/,CONNECTION:Keep-Alive,ACCEPT-ENCODING:gzip\x2c deflate,ACCEPT-LANGUAGE:en-us     3
# dtype: int64
#
# <<< params >>>
# (empty)                                                         75
# ver                                                             10
# )%20format("eot")\x2c%20url(http://www.kitchenboss.com.au/wp-content/themes/kitchenboss_v1/Aovel_Sans_Rounded/ASansrounded.woff)%20format("woff")\x2c%20url(http://www.kitchenboss.com.au/wp-content/themes/kitchenboss_v1/Aovel_Sans_Rounded/ASansrounded.ttf)%20format("truetype")\x2c%20url(http://www.kitchenboss.com.au/wp-content/themes/kitchenboss_v1/Aovel_Sans_Rounded/ASansrounded.svg     2
# family                                                           2
# )%20format("eot")\x2c%20url(ASansrounded.woff)%20format("woff")\x2c%20url(ASansrounded.ttf)%20format("truetype")\x2c%20url(ASansrounded.svg     2
# dtype: int64
#
# <<< referrer >>>
# http://www.kitchenboss.com.au/                  80
# http://p22x62n0yr63872e-qh6.focondteavrt.ru/     1
# dtype: int64
#
# <<< request_body_len >>>
# 0    94
# dtype: int64
#
# <<< resp_body_length >>>
# 18643    5
# 13944    2
# 7724     2
# 86154    2
# 35       2
# dtype: int64
#
# <<< resp_fuids >>>
# FM7QC03F1iO5QiyIjh    1
# FaNPECf9WgxoibQXl     1
# FCFGzKgVLi5yIkxvj     1
# Fm1yOv4BaLPmCmHth8    1
# FTdqze4bVSU9gvBd67    1
# dtype: int64
#
# <<< resp_heads >>>
# DATE:Wed\x2c 09 Apr 2014 06:39:36 GMT,CONNECTION:close,SERVER:Apache    14
# DATE:Wed\x2c 09 Apr 2014 06:39:37 GMT,CONNECTION:close,SERVER:Apache    11
# CONNECTION:close,DATE:Wed\x2c 09 Apr 2014 06:39:35 GMT,SERVER:Apache     5
# DATE:Wed\x2c 09 Apr 2014 06:39:46 GMT,X-POWERED-BY:PHP/5.3.27,SERVER:nginx/0.7.67,VARY:User-Agent,CONTENT-TYPE:application/java,CONTENT-LENGTH:18643,ACCEPT-RANGES:bytes,CONTENT-DISPOSITION:inline; filename=2496128308.jar,CONNECTION:keep-alive     2
# CONTENT-TYPE:application/x-shockwave-flash,DATE:Wed\x2c 09 Apr 2014 06:38:59 GMT,CONTENT-LENGTH:7724,ACCEPT-RANGES:bytes,CONNECTION:close,LAST-MODIFIED:Tue\x2c 11 Feb 2014 12:18:21 GMT,SERVER:Apache     2
# dtype: int64
#
# <<< resp_mime_types >>>
# text/plain         17
# image/png          13
# application/jar     5
# image/jpeg          5
# text/html           5
# dtype: int64
#
# <<< response_body_len >>>
# 0        39
# 18643     5
# 13944     2
# 86154     2
# 7724      2
# dtype: int64
#
# <<< status_code >>>
# 200    57
# 304    35
# 301     2
# dtype: int64
#
# <<< status_msg >>>
# OK                   57
# Not Modified         35
# Moved Permanently     2
# dtype: int64
#
# <<< tags >>>
# (empty)    94
# dtype: int64
#
# <<< trans_depth >>>
# 1    87
# 2     4
# 3     2
# 4     1
# dtype: int64
#
# <<< ts >>>
# 1.397026e+09    1
# 1.397026e+09    1
# 1.397026e+09    1
# 1.397026e+09    1
# 1.397026e+09    1
# dtype: int64
#
# <<< uid >>>
# CkDgnq2lmEjrUAj23e    4
# Ckoq2A2W1MgyXIwTGe    3
# CDtV0V11MOzimGgT89    2
# CMN3lm4lKUHSyGw8kh    2
# CrtpF2FjrA76UgJR3     1
# dtype: int64
#
# <<< uri >>>
# /1397004360.jar                                           5
# /                                                         5
# /wp-content/plugins/sitemap/css/page-list.css?ver=4.2     2
# /wp-content/themes/kitchenboss_v1/images/footer_bg.png    2
# /wp-content/themes/kitchenboss_v1/images/menu_bg.png      2
# dtype: int64
#
# <<< user_agent >>>
# Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    87
# Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10                       7
# dtype: int64
#
# <<< time >>>
# 2014-04-09 06:38:58.167349    1
# 2014-04-09 06:39:38.171185    1
# 2014-04-09 06:39:37.624519    1
# 2014-04-09 06:38:57.816832    1
# 2014-04-09 06:39:36.882124    1
# dtype: int64

# %%
# Explore pivoting and resampling
response_bytes = df[['time','resp_mime_types','response_body_len']]
response_bytes['response_body_len'] = response_bytes['response_body_len'].astype(int)
print response_bytes.head()
pivot = pd.pivot_table(response_bytes, rows='time', values='response_body_len', cols=['resp_mime_types'], aggfunc=sum)
sampled_bytes = pivot.resample('1S', how='sum')
sampled_bytes.head()
# Out:
#                         time resp_mime_types  response_body_len
# 0 2014-04-09 06:38:54.686325             NaN                  0
# 1 2014-04-09 06:38:55.549895       text/html              13944
# 2 2014-04-09 06:38:56.958887      text/plain                 98
# 3 2014-04-09 06:38:56.983591      text/plain              10220
# 4 2014-04-09 06:38:56.983314       text/html               2429
#
# [5 rows x 3 columns]
# resp_mime_types      application/jar  application/pdf  \
# time
# 2014-04-09 06:38:55              NaN              NaN
# 2014-04-09 06:38:56              NaN              NaN
# 2014-04-09 06:38:57              NaN              NaN
# 2014-04-09 06:38:58              NaN              NaN
# 2014-04-09 06:38:59              NaN              NaN
#
# resp_mime_types      application/vnd.ms-fontobject  application/x-dosexec  \
# time
# 2014-04-09 06:38:55                            NaN                    NaN
# 2014-04-09 06:38:56                            NaN                    NaN
# 2014-04-09 06:38:57                            NaN                    NaN
# 2014-04-09 06:38:58                         104731                    NaN
# 2014-04-09 06:38:59                          86154                    NaN
#
# resp_mime_types      application/x-shockwave-flash  image/gif  image/jpeg  \
# time
# 2014-04-09 06:38:55                            NaN        NaN         NaN
# 2014-04-09 06:38:56                            NaN        NaN         NaN
# 2014-04-09 06:38:57                            NaN        NaN         NaN
# 2014-04-09 06:38:58                            NaN        NaN         NaN
# 2014-04-09 06:38:59                            NaN         35      280281
#
# resp_mime_types      image/png  text/html  text/plain
# time
# 2014-04-09 06:38:55        NaN      13944         NaN
# 2014-04-09 06:38:56        NaN       6451      129638
# 2014-04-09 06:38:57        NaN        NaN        7989
# 2014-04-09 06:38:58        NaN        NaN       29237
# 2014-04-09 06:38:59     137128        NaN       40149
#
# [5 rows x 10 columns]

# %%
response_bytes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 0 to 93
# Data columns (total 3 columns):
# time                 94 non-null datetime64[ns]
# resp_mime_types      55 non-null object
# response_body_len    94 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)

# %%
sampled_bytes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45 entries, 2014-04-09 06:38:55 to 2014-04-09 06:39:39
# Freq: S
# Data columns (total 10 columns):
# application/jar                  4 non-null float64
# application/pdf                  1 non-null float64
# application/vnd.ms-fontobject    2 non-null float64
# application/x-dosexec            1 non-null float64
# application/x-shockwave-flash    1 non-null float64
# image/gif                        3 non-null float64
# image/jpeg                       2 non-null float64
# image/png                        4 non-null float64
# text/html                        4 non-null float64
# text/plain                       7 non-null float64
# dtypes: float64(10)

# %%
# Let plot it!
sampled_bytes.plot()

# %%
# Although the plot below looks 'nicer' we have to be SUPER careful with interplolation 
# of any kind as it can often misrepresent the actual data.
interp = sampled_bytes.interpolate(method='linear')
interp.plot()

# %%
sampled_bytes_min = pivot.resample('.1s', how='sum')
sampled_bytes_min.plot()

# %%
interp_min = sampled_bytes_min.interpolate(method='linear')
interp_min.plot()

# %% [markdown]
# <div style="float: left; margin: 0px 30px 0px 0px"><img src="files/images/processing_data.jpg" width="250px"></div>
# # Process the Data
# We're going to use some nice functionality in the Pandas dataframe to process our data:
#
#     - We have both client and server events, just keep the client events for this exercise
#     - Transform the complicated user-agent string into something more managable (short-agent)
#     - Generate a 'feature vector' from the header keys
