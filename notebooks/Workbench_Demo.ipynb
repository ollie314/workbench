# %% [markdown]
# # Workbench:
# An exploration of a light-weight and flexible approach to task management and execution.
# ## Goals of the Exploration:
# Open source tools have 3 primarly components that are critical for adoption:
#
#   - ### How easy is it to get the system up and running?
#     - git clone https://github.com/ClickSecurity/workbench.git
#     - pip install -U pymongo
#     - pip install -U zerorpc
#     - cd workbench/server; python workbench.py
#
#   - ### How easy is it to use?
#     - ZeroRPC has Python, Node.js, or CLI interfaces.
#   <pre>
#     import zerorpc
#     c = zerorpc.Client()
#     c.connect("tcp://127.0.0.1:4242")
#     with open(filename,'rb') as f:
#         md5 = c.load_sample(filename, f.read())
#         results = c.work_request('report', md5)
#   </pre>
#   - ### How easy is it for me to put my own code into it?
#     - Below is the listing of the code for the 'strings' worker: Each worker needs to provide:
#         - plugin_info (name, class of the worker, dependencies, and description)
#         - An execute method that takes a python dictionary as input and returns a python dictionary as output.
#         - That's it...
# <pre>
#     ''' Strings worker '''
#     import re
#     def plugin_info():
#             return {'name':'strings', 'class':'Strings', 'dependencies': ['sample'],
#                     'description': 'This worker extracts all the strings from any type of file. Output keys: [string_list]'}
#     class Strings():
#             def __init__(self):
#                 self.find_strings = re.compile(r'[^\x00-\x1F\x7F-\xFF]{4,}', re.MULTILINE)
#             def execute(self, input_data):
#                 raw_bytes = input_data['sample']['raw_bytes']
#                 strings = self.find_strings.findall(raw_bytes)
#                 return {'string_list': strings}
# </pre>
#
# # On with the demo, lets start up the workbench server...
# Run the workbench server (from somewhere, for the demo we're just going to start a local one)
# <pre>
# > cd workbench/server
# > python workbench.py
# </pre>
#
# #### Okay so when the server starts up, it autoloads any worker plugins in the server/worker directory and dynamically monitors the directory, if a new python file shows up, it's validated as a properly formed plugin and if it passes is added to the list of workers.

# %%
# Lets start to interact with workbench, please note there is NO specific client to workbench,
# Just use the ZeroRPC Python, Node.js, or CLI interfaces.
import zerorpc
c = zerorpc.Client()
c.connect("tcp://127.0.0.1:4242")
# Out:
# [None]

# %%
# Want to find out about what's on the other side?
print c._zerorpc_name()
print c._zerorpc_list()
# Out:
# workbench
# ['set_datastore_uri', 'have_sample', 'search', 'get_datastore_uri', 'work_request', 'worker_info', 'store_sample', 'get_sample', 'batch_work_request', 'index_worker_output', 'stream_sample', 'els_index_sample']

# %%
# Okay so we see that we're connected to workbench and the calls we can make
# The 'worker_info' call look interesting...
c.worker_info()
# Out:
# {'json_meta': 'This worker computes a meta-data for log files. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'log_meta': 'This worker computes a meta-data for log files. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'meta': 'This worker computes meta-data. Output keys: [md5, type_tag, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'meta_deep': 'This worker computes deeper meta-data. Output keys: [md5, sha1, sha256, ssdeep, entropy, file_type, mime_type, encoding, file_size, filename, import_time]',
#  'pcap_bro': 'This worker runs Bro scripts on a pcap file. Output keys: [log_name:md5...]',
#  'pcap_meta': 'This worker computes a bunch of meta-data about a pcap file. Output keys: [summary, sessions]',
#  'pe_classifier': 'This worker classifies PEFiles as Evil or Benign. Output keys: [classification]',
#  'pe_features': 'This worker pulls out a bunch of static features from a PEFile. Output keys: [dense_features, sparse_features]',
#  'pe_indicators': 'This worker uses the static features from the pefile module to look for weird stuff.  Output keys: [indicator_list]',
#  'pe_peid': 'This worker using the peid database to look for signatures in a PEFile. Output keys: [match_list]',
#  'strings': 'This worker extracts all the strings from any type of file. Output keys: [string_list]',
#  'unzip': 'This worker unzips a zipped file. Output keys: [payload_md5s]',
#  'urls': 'This worker looks for url patterns in strings output. Output keys: [url_list]',
#  'view': 'This worker generates a view for any type of file. Output keys: [this view calls sub-views, see the concrete class (view_pdf for instance)]',
#  'view_customer': 'This worker generates a customer usage view. Output keys: [filename, md5, length, customer, upload_date]',
#  'view_log_meta': 'This worker generates a view for log meta. Output keys: [mime_type, encoding, import_time, file_size]',
#  'view_meta': 'This worker generates a view for meta about a sample. Output keys: [mime_type, encoding, import_time, ssdeep, entropy, file_size]',
#  'view_pcap_bro': 'This worker generates a pcap view for the sample. Output keys: [bro_output_log_names...]',
#  'view_pcap_meta': 'This worker generates a pcap view for the sample. Output keys: [import_time, entropy, file_size, summary, sessions]',
#  'view_pdf': 'This worker generates a view for a PDF File. Output keys: [filename, filetype, mime_type, encoding, import_time, ssdeep, strings]',
#  'view_pefile': 'This worker generates a view for a PE File. Output keys: [filename, filetype, mime_type, encoding, import_time, ssdeep, indicators, peid_Matches, classification, disass]',
#  'view_zip': 'This worker generates a view for a zip File. Output keys: [filename, filetype, mime_type, payload_md5s, payload_meta]'}

# %%
# So we can see all the available workers lets load up a file and run some stuff
# Okay when we load up a file, we get the md5 back
filename = '../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e21ac0f3'
with open(filename,'rb') as f:
    md5 = c.store_sample(filename, f.read(),'pe')
print md5
# Out:
# 0cb9aa6fb9c4aa3afad7a303e21ac0f3

# %%
# Now lets get the meda data for this file
c.work_request('meta', md5)
# Out:
# {'meta': {'encoding': 'binary',
#   'file_size': 20480,
#   'file_type': 'PE32 executable (GUI) Intel 80386, for MS Windows',
#   'filename': '../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e21ac0f3',
#   'import_time': '2014-03-13T20:07:36.416000Z',
#   'md5': '0cb9aa6fb9c4aa3afad7a303e21ac0f3',
#   'mime_type': 'application/x-dosexec',
#   'type_tag': 'pe'}}

# %%
# Lets randomly try some workers
c.work_request('pe_classifier', md5)
# Out:
# {'pe_classifier': {'classification': 'Evil!',
#   'md5': '0cb9aa6fb9c4aa3afad7a303e21ac0f3'}}

# %%
# Ah, ha.. I knew that file was evil!  :)

# Okay, that worker needed the output of pe_features and pe_indicators
# so what happened? The worker has a dependency list and workbench
# recursively satisfies that dependency list.. this is powerful because
# when we're interested in one particular analysis we just want to get
# the darn thing without having to worry about a bunch of details

# Well lets do this for a bunch of files!
import os
file_list = [os.path.join('../test_files/pe/bad', child) for child in os.listdir('../test_files/pe/bad')]
working_set = []
for filename in file_list:
    with open(filename,'rb') as f:
        md5 = c.store_sample(filename, f.read(), 'pe')
        results = c.work_request('pe_classifier', md5)
        working_set.append(md5)
        print 'Results: %s' % (results)
# Out:
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '033d91aae8ad29ed9fbb858179271232'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '0cb9aa6fb9c4aa3afad7a303e21ac0f3'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '0e882ec9b485979ea84c7843d41ba36f'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': '0e8b030fb6ae48ffd29e520fc16b5641'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': '0eb9e990c521b30428a379700ec5ab3e'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '127f2bade752445b3dbf2cf2ea75c201'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '139385a91b9bca0833bdc1fa77e42b91'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '13dcc5b4570180118eb65529b77f6d89'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '1cac80a2147cd8f3860547e43edcaa00'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '1cea13cf888cd8ce4f869029f1dbb601'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '1d733a9e3e571ce5f5f633a0cfd3d5f0'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2058c50de5976c67a09dfa5e0e1c7eb5'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d012cba541c22fb7250975d5ad0d065'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d015553c7388e4d78f05b24aba0819c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d017ff228c39a0a727586b33f8168b0'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09133abb48e1c7f3f5c8f8ced8fef4'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d094b6c69020091b68d1bcf5d11fa4b'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d095091983dd0bf6ab7c0bb6dd695f9'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09546831b17d2cc0583362b6d312ae'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d099171876f7301c155bd775fff2b6a'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': '2d09a573b0e9d02a9fa47b16e9c01a48'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09b5768e3617523d8afa110361919c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09b8d9852c3176259915e3509bcbd1'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09ca902990545fec9ac190b0338b50'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09cb38c268aa9297e5a7f27e677267'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09cc92bbe29d96bb3a91b350d1725f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09e4aff42aebac87ae2fd737aba94f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '32b24e73cfc3ac4c43f1926f8935e438'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '4ed28b6207560f127d267de639a4e1bf'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '505804ec7c7212a52ec85e075b91ed84'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '60a83c049e135cc199138c1f8861437c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '69f9633fa6fd5dc1fd917cb435bba8ad'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '79f5e1af9fdb92476045989bda7515c7'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '7f313447b887b078215617fbed1a34a1'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '8006782bdf703e2f3fdf1d1650f45ffd'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '86714940f491bc38c2e842e80c7f778e'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '987bd46899b2a9493e6dec051edcb66c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '9cd3d7b1b0f2aea5950cbf7d97776f2f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '9ceccd9f32cb2ad0b140b6d15d8993b6'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '9e42ff1e6f75ae3e60b24e48367c8f26'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'a7b0a9067d8292b252d741e6fae17cd9'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': 'afddc552b31a8f2438768c73674bf29e'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'b681485cb9e0cad73ee85b9274c0d3c2'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'bf1249a258cbcccec0f1b4ea1e9451a1'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'c8c54ac7e827056174762c68db84534f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'cc113aa59c04b17e7cb832fc417f104d'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': 'd94da41e7e809f7366971b3b50f8ef68'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'e9a6c83826deacfbc2281b6c7e401694'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'ea5d95c96a23b21b9038f03b91955c18'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'f6190648c2efb764ae1d73b0e9a4fd13'}}

# %%
# We just ran the classifer on 50 files and you'll note that we ONLY got back the
# information we ask for. On a large amount of files (100k or greater) if you don't
# have a granular system, something this easy WILL NOT BE POSSIBLE! (dramatic enough?)

# So lets look at the features going into the classifier (btw the classifier is current a toy example)
c.work_request('pe_features', md5)
# Out:
# {'pe_features': {'dense_features': {'check_sum': 0,
#    'compile_date': 1074901182,
#    'datadir_IMAGE_DIRECTORY_ENTRY_BASERELOC_size': 2348796035,
#    'datadir_IMAGE_DIRECTORY_ENTRY_EXPORT_size': 0,
#    'datadir_IMAGE_DIRECTORY_ENTRY_IAT_size': 0,
#    'datadir_IMAGE_DIRECTORY_ENTRY_IMPORT_size': 20,
#    'datadir_IMAGE_DIRECTORY_ENTRY_RESOURCE_size': 262,
#    'debug_size': 0,
#    'export_size': 0,
#    'generated_check_sum': 62500,
#    'iat_rva': 86510,
#    'major_version': 0,
#    'minor_version': 57,
#    'number_of_bound_import_symbols': 0,
#    'number_of_bound_imports': 0,
#    'number_of_export_symbols': 0,
#    'number_of_import_symbols': 0,
#    'number_of_imports': 0,
#    'number_of_rva_and_sizes': 10,
#    'number_of_sections': 3,
#    'pe_char': 33167,
#    'pe_dll': 0,
#    'pe_driver': 0,
#    'pe_exe': 1,
#    'pe_i386': 1,
#    'pe_majorlink': 76,
#    'pe_minorlink': 111,
#    'pe_warnings': 1,
#    'sec_entropy_': 7.876937179741062,
#    'sec_entropy_@': 5.388003199139927,
#    'sec_entropy_data': 0,
#    'sec_entropy_ps': 5.388003199139927,
#    'sec_entropy_rdata': 0,
#    'sec_entropy_reloc': 0,
#    'sec_entropy_rsrc': 0,
#    'sec_entropy_text': 0,
#    'sec_raw_execsize': 6984,
#    'sec_rawptr_': 512,
#    'sec_rawptr_@': 16,
#    'sec_rawptr_data': 0,
#    'sec_rawptr_ps': 16,
#    'sec_rawptr_rsrc': 0,
#    'sec_rawptr_text': 0,
#    'sec_rawsize_': 5992,
#    'sec_rawsize_@': 496,
#    'sec_rawsize_data': 0,
#    'sec_rawsize_ps': 496,
#    'sec_rawsize_rsrc': 0,
#    'sec_rawsize_text': 0,
#    'sec_va_execsize': 86016,
#    'sec_vasize_': 36864,
#    'sec_vasize_@': 4096,
#    'sec_vasize_data': 0,
#    'sec_vasize_ps': 45056,
#    'sec_vasize_rsrc': 0,
#    'sec_vasize_text': 0,
#    'size_code': 1766614113,
#    'size_image': 90112,
#    'size_initdata': 1918988898,
#    'size_uninit': 16761,
#    'std_section_names': 0,
#    'total_size_pe': 6504,
#    'virtual_address': 4096,
#    'virtual_size': 45056,
#    'virtual_size_2': 36864},
#   'md5': 'f6190648c2efb764ae1d73b0e9a4fd13',
#   'sparse_features': {'imported_symbols': 0,
#    'pe_warning_strings': ['Error parsing section 0. PointerToRawData should normally be a multiple of FileAlignment, this might imply the file is trying to confuse tools which parse this incorrectly',
#     'Suspicious flags set for section 0. Both IMAGE_SCN_MEM_WRITE and IMAGE_SCN_MEM_EXECUTE are set. This might indicate a packed executable.',
#     'Suspicious flags set for section 1. Both IMAGE_SCN_MEM_WRITE and IMAGE_SCN_MEM_EXECUTE are set. This might indicate a packed executable.',
#     'Error parsing section 2. PointerToRawData should normally be a multiple of FileAlignment, this might imply the file is trying to confuse tools which parse this incorrectly',
#     'Suspicious flags set for section 2. Both IMAGE_SCN_MEM_WRITE and IMAGE_SCN_MEM_EXECUTE are set. This might indicate a packed executable.',
#     'Corrupt header "IMAGE_IMPORT_DESCRIPTOR" at file offset 494. Exception: \'Data length less than expected header length.\'',
#     "Invalid relocation information. Can't read data at RVA: 0x476ffa5"],
#    'section_names': ['ps', '', '@']}}}

# %%
c.work_request('pe_indicators', md5)
# Out:
# {'pe_indicators': {'indicator_list': [{'category': 'PE_WARN',
#     'description': 'Error parsing section 0. PointerToRawData should normally be a multiple of FileAlignment, this might imply the file is trying to confuse tools which parse this incorrectly',
#     'severity': 2},
#    {'category': 'PE_WARN',
#     'description': 'Suspicious flags set for section 0. Both IMAGE_SCN_MEM_WRITE and IMAGE_SCN_MEM_EXECUTE are set. This might indicate a packed executable.',
#     'severity': 2},
#    {'category': 'PE_WARN',
#     'description': 'Suspicious flags set for section 1. Both IMAGE_SCN_MEM_WRITE and IMAGE_SCN_MEM_EXECUTE are set. This might indicate a packed executable.',
#     'severity': 2},
#    {'category': 'PE_WARN',
#     'description': 'Error parsing section 2. PointerToRawData should normally be a multiple of FileAlignment, this might imply the file is trying to confuse tools which parse this incorrectly',
#     'severity': 2},
#    {'category': 'PE_WARN',
#     'description': 'Suspicious flags set for section 2. Both IMAGE_SCN_MEM_WRITE and IMAGE_SCN_MEM_EXECUTE are set. This might indicate a packed executable.',
#     'severity': 2},
#    {'category': 'PE_WARN',
#     'description': 'Corrupt header "IMAGE_IMPORT_DESCRIPTOR" at file offset 494. Exception: \'Data length less than expected header length.\'',
#     'severity': 2},
#    {'category': 'PE_WARN',
#     'description': "Invalid relocation information. Can't read data at RVA: 0x476ffa5",
#     'severity': 2},
#    {'category': 'MALFORMED', 'description': 'Checksum of Zero', 'severity': 1},
#    {'category': 'MALFORMED',
#     'description': 'Reported Checksum does not match actual checksum',
#     'severity': 2},
#    {'category': 'MALFORMED',
#     'description': 'Image size does not match reported size',
#     'severity': 3},
#    {'attributes': ['ps', '', '@'],
#     'category': 'MALFORMED',
#     'description': 'Section(s) with a non-standard name, tamper indication',
#     'severity': 3},
#    {'attributes': ['PS', '@\x00\x0f@\x00'],
#     'category': 'MALFORMED',
#     'description': 'Unaligned section, tamper indication',
#     'severity': 3}],
#   'md5': 'f6190648c2efb764ae1d73b0e9a4fd13'}}

# %%
# Wow, that's a lot of features... if I had to flood my network, and parse 
# through all that shit just to get my one line of classification results,
# I might prefer some nutshots from a kid wearing a football helmet.

# On another note, did we just waste some time there? Did workbench have
# to recompute the features? No everything done by workbench is pushed into the MongoDB
# backend and then if the work results for that md5 are already in the datastore the
# a very lightweight call is made to get the results. In fact results are never directly
# returned, the worker pushes into Mongo and then we pull them out and hand them to the
# client, that way we ^ensure^ that the bits in the datastore and the bits that you get
# are the exact same 'gold bits' (seems like overkill but it's important).

# Lets look at the datastore now.
import pymongo
uri = c.get_datastore_uri()
mongo_c = pymongo.MongoClient(uri)
db = mongo_c.get_default_database()

# %%
# Every worker pushes it's results to a separate collection
db.collection_names()
# Out:
# [u'system.indexes',
#  u'fs.chunks',
#  u'samples',
#  u'fs.files',
#  u'meta',
#  u'pe_features',
#  u'pe_indicators',
#  u'pe_classifier']

# %%
# What if something weird happened like one of the collections got deleted?
# Hey lets find out
db.pe_classifier.drop()
db.collection_names()
# Out:
# [u'system.indexes',
#  u'fs.chunks',
#  u'samples',
#  u'fs.files',
#  u'meta',
#  u'pe_features',
#  u'pe_indicators']

# %%
# Okay.. so the system will flop over and die now.. yes?  No, in fact removing
# a collection is fine. Watch the magic...
#
for md5 in working_set:
    results = c.work_request('pe_classifier', md5)
    print 'Results: %s' % (results)
# Out:
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '033d91aae8ad29ed9fbb858179271232'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '0cb9aa6fb9c4aa3afad7a303e21ac0f3'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '0e882ec9b485979ea84c7843d41ba36f'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': '0e8b030fb6ae48ffd29e520fc16b5641'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': '0eb9e990c521b30428a379700ec5ab3e'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '127f2bade752445b3dbf2cf2ea75c201'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '139385a91b9bca0833bdc1fa77e42b91'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '13dcc5b4570180118eb65529b77f6d89'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '1cac80a2147cd8f3860547e43edcaa00'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '1cea13cf888cd8ce4f869029f1dbb601'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '1d733a9e3e571ce5f5f633a0cfd3d5f0'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2058c50de5976c67a09dfa5e0e1c7eb5'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d012cba541c22fb7250975d5ad0d065'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d015553c7388e4d78f05b24aba0819c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d017ff228c39a0a727586b33f8168b0'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09133abb48e1c7f3f5c8f8ced8fef4'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d094b6c69020091b68d1bcf5d11fa4b'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d095091983dd0bf6ab7c0bb6dd695f9'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09546831b17d2cc0583362b6d312ae'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d099171876f7301c155bd775fff2b6a'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': '2d09a573b0e9d02a9fa47b16e9c01a48'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09b5768e3617523d8afa110361919c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09b8d9852c3176259915e3509bcbd1'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09ca902990545fec9ac190b0338b50'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09cb38c268aa9297e5a7f27e677267'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09cc92bbe29d96bb3a91b350d1725f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '2d09e4aff42aebac87ae2fd737aba94f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '32b24e73cfc3ac4c43f1926f8935e438'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '4ed28b6207560f127d267de639a4e1bf'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '505804ec7c7212a52ec85e075b91ed84'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '60a83c049e135cc199138c1f8861437c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '69f9633fa6fd5dc1fd917cb435bba8ad'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '79f5e1af9fdb92476045989bda7515c7'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '7f313447b887b078215617fbed1a34a1'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '8006782bdf703e2f3fdf1d1650f45ffd'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '86714940f491bc38c2e842e80c7f778e'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '987bd46899b2a9493e6dec051edcb66c'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '9cd3d7b1b0f2aea5950cbf7d97776f2f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '9ceccd9f32cb2ad0b140b6d15d8993b6'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': '9e42ff1e6f75ae3e60b24e48367c8f26'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'a7b0a9067d8292b252d741e6fae17cd9'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': 'afddc552b31a8f2438768c73674bf29e'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'b681485cb9e0cad73ee85b9274c0d3c2'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'bf1249a258cbcccec0f1b4ea1e9451a1'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'c8c54ac7e827056174762c68db84534f'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'cc113aa59c04b17e7cb832fc417f104d'}}
# Results: {'pe_classifier': {'classification': 'Benign', 'md5': 'd94da41e7e809f7366971b3b50f8ef68'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'e9a6c83826deacfbc2281b6c7e401694'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'ea5d95c96a23b21b9038f03b91955c18'}}
# Results: {'pe_classifier': {'classification': 'Evil!', 'md5': 'f6190648c2efb764ae1d73b0e9a4fd13'}}

# %%
# wow, that was super underwhelming.. stuff just worked...
db.collection_names()
# Out:
# [u'system.indexes',
#  u'fs.chunks',
#  u'samples',
#  u'fs.files',
#  u'meta',
#  u'pe_features',
#  u'pe_indicators',
#  u'pe_classifier']

# %%
# Another example.. I want to look at strings for different types of files (not just pe_files)
# So we can load up a few pdfs (the pe's are already in the datastore)
file_list = [os.path.join('../test_files/pdf/bad', child) for child in os.listdir('../test_files/pdf/bad')]
for filename in file_list:
    with open(filename,'rb') as f:
        md5 = c.store_sample(filename, f.read(), 'pdf')
        working_set.append(md5)

# %%
# Now we rip the strings worker on them all
for md5 in working_set:
    result = c.work_request('strings', md5)
    print 'results: %s' % (result['strings']['string_list'][:5]) # strings output is large so just showing the first 5
# Out:
# results: ['    ', '!This program cannot be run in DOS mode.', 'Rich', '.text', '.rdata']
# results: ['!This program cannot be run in DOS mode.', 'Rich3', '.text', '`.rdata', '@.data']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`.data', '.rsrc']
# results: ['This program must be run under Win32', 'CODE', '`DATA', '.idata', '.tls']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`.rdata', '@DATA']
# results: ['!This program cannot be run in DOS mode.', 'kRich', '.text', '`.rdata', '@.data']
# results: ['!This program cannot be run in DOS mode.', '.text', '.code', '`.data', '.data3']
# results: ['!This program cannot be run in DOS mode.', 'YRich', '.text', '`.rdata', '@.data']
# results: ['!This program cannot be run in DOS mode.', '.text', '`.data', '.rsrc', 'blenkxr']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`.rdata', '@.data']
# results: ['!This program cannot be run in DOS mode.', '.text', '.data', '.rsrc', 'aitrfvl']
# results: ['This program must be run under Win32', 'ATSEC0', '`ATSEC1', '@ATSEC2', '@idata']
# results: ['This program must be run under Win32', 'CODE', '`DATA', '.idata', '.reloc']
# results: ['yrf<[LordPE]', '.text', '.text', 'ExitProcess', 'KERNEL32.dll']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`rdata', '.data']
# results: ['!This program cannot be run in DOS mode.', '6Rich#', '^"+M', 'UPX0', 'UPX1']
# results: ['!This program cannot be run in DOS mode.', 'Rich"', '.text', '@.code', '`.data']
# results: ['yrf<[LordPE]', '.text', '.text', 'ExitProcess', 'KERNEL32.dll']
# results: ['!This program cannot be run in DOS mode.', 'Riche', '.text', '.data', '.rsrc']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`rdata', '.data']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.data', '`.data', '`.data']
# results: ['!This program cannot be run in DOS mode.', '.text', '`.data', '.idata', '@.rsrc']
# results: ['!This program cannot be run in DOS mode.', ">O'X_!tX_!tX_!t", '@+tN_!t', 'C/tR_!t:@2tS_!tX_ t', '@*t[_!t']
# results: ['!This program cannot be run in DOS mode.', 'RichX', 'E0TK', '.text', '`.rdata']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`rdata', '.data']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`.rdata', '@.data']
# results: ['!This program cannot be run in DOS mode.', 'UPX0', 'UPX1', '.rsrc', '3.03']
# results: ['    ', '!This program cannot be run in DOS mode.', 'Rich', '.text', '.rdata']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.data', '.pdata', '.ex_cod']
# results: ['This program must be run under Win32', 'CODE', '`DATA', '.idata', '.tls']
# results: ['!This program cannot be run in DOS mode.', '.text', '`.rdata', '@.data', '_TEXT2']
# results: ['!This program cannot be run in DOS mode.', 'ERich', 'UPX0', 'UPX1', 'UPX2']
# results: ['This program must be run under Win32', 'mnYD', 'CODE', '`DATA', '.idata']
# results: ['!This program cannot be run in DOS mode.', '.text', '`.rdata', '@.data', '_TEXT2']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.PEX', '`.PEX', 'Bome']
# results: ['!This program cannot be run in DOS mode.', '|Richv', 'UPX0', 'UPX1', '.rsrc']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', '`.rdata', '@.data']
# results: ['!This program cannot be run in DOS mode.', 'sIPE', '.text', '.data', '.rsrc']
# results: ['!This program cannot be run in DOS mode.', '.text', '.data', '.rsrc', 'mzphdwa']
# results: ['!This program cannot be run in DOS mode.', '.text', '.data', '.rsrc', 'lsicbkg']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.packed', '`.RLPack', 'a?/u']
# results: ['!This program cannot be run in DOS mode.', 'Rich', '.text', 'h.rdata', 'H.reloc']
# results: ['This program must be run under Win32', 'CODE', '`DATA', '.idata', '.tls']
# results: ['    ', '!This program cannot be run in DOS mode.', 'Rich', '.text', '.rdata']
# results: ['!This program cannot be run in DOS mode.', '.text', '.data', '.rdata', '@.bss']
# results: ['!This program cannot be run in DOS mode.', 'ssaR', "'#K'", '.data', '.text']
# results: ['!This program cannot be run in DOS mode.', 'BZ.`', 'Richy', 'J!NH', '.text']
# results: ['!This program cannot be run in DOS mode.', 'RichW', '.text', '.data', '.rsrc']
# results: ['.text', 'KERNEL32.DLL', 'MSVCRT.DLL', 'USER32.DLL', 'ADVAPI32.DLL']
# results: ['MZKERNEL32.DLL', 'LoadLibraryA', 'GetProcAddress', '^]YF', 'W8mu']
# results: ['%PDF-1.6', '52 0 obj<</Length 51252212/Root 1 0 R/Info 3 0 R%/F/W[1 2 1]/Index[5 1 7 1 9 4 23 4 50 3]>>stream', '/Filter/FlateDecode/W[1 2 1]/Index[5 1 7 1 9 4 23 4 50 3]>>stream', 'bbb0b`b```', '310Z']
# results: ['%PDF-1.1', '1 0 obj', ' /Type /Catalog', ' /Outlines 2 0 R', ' /Pages 3 0 R']
# results: ['%PDF-1.3', '2 0 obj', '/OpenAction << /JS 9 0 R /S /JavaScript >>', '/Type /Catalog', '/Pages 3 0 R']
# results: ['%PDF-1.4', '1 0 obj', '/Type /Catalog', '/Outlines 3 0 R', '/Pages 4 0 R']
# results: ['%PDF-1.6', '11 0 obj', '<</Filter/FlateDecode /Length 2523>>', 'stream', 's--e']
# results: ['%PDF-1.4', '1 0 obj', '<</Pages 2 0 R  /OpenAction <<', '/JS 4 0 R /S /JavaScript /Type /Catalog>>>>', 'endobj']
# results: ['%PDF-1.0', '1 0 obj<</Type/Catalog/Pages 2 0 R /Names 3 0 R >>endobj', '2 0 obj<</Type/Pages/Count 1/Kids[ 4 0 R ]>>endobj', '3 0 obj<</JavaScript 5 0 R >>endobj', '4 0 obj<</Type/Page/Parent 2 0 R /Contents 12 0 R>>endobj']
# results: ['%PDF-1.6', '7 0 obj', '<</Count 1/Type/Pages/Kids[28 0 R]>>', 'endobj', '21 0 obj']
# results: ['%PDF-1.3', '4 0 obj', 'endobj', '5 0 obj', '/Producer (substr)']
# results: ['%PDF-1.5', '1 0 obj<</#54ype/#43atal#6fg/Outlin#65#73 2 0 R/#50ages 3 0 R/Ope#6e#41ctio#6e 5 0 R>>endobj', '2 0 obj<</T#79#70#65/#4fu#74li#6e#65s/C#6funt 0>>endobj', '3 0 obj<</Ty#70#65/Pa#67#65s/K#69ds[4 0 R]/#43o#75nt 1>>endobj', '4 0 obj<</#54#79pe/P#61g#65/#50a#72#65#6et 3 0 R/#4d#65#64i#61B#6f#78[0 0 612 792]>>endobj']
# results: ['%PDF-1.3', '4 0 obj', '<< /Length 5 0 R /Filter /FlateDecode >>', 'stream', '}b%~T\\']
# results: ['%PDF-1.7', '3 0 obj', '<</Type /Page', '/Parent 1 0 R', '/MediaBox [0 0 595.28 841.89]']
# results: ['%PDF-1.3', '%&#1074;&#1075;&#1055;&#1059;', '1 0 obj', '/Outlines 2 0 R', '/OpenAction 3 0 R']
# results: ['%PDF-1.6', '10 0 obj', '<</Filter/FlateDecode /Length 1563>>', 'stream', '}V]o']
# results: ['%PDF-1.3', '3 0 obj', '<</Type /Page', '/Parent 1 0 R', '/Resources 2 0 R']
# results: ['%PDF-1.6', '12 0 obj', '<</Filter/FlateDecode /Length 2063>>', 'stream', 'W1OOO']
# results: ['%PDF-1.4', '1 0 obj', '/Type /Catalog', '/Outlines 3 0 R', '/Pages 4 0 R']
# results: ['%PDF-1.0', '1 0 obj<</Type/Catalog/Pages 2 0 R /Names 3 0 R >>endobj', '2 0 obj<</Type/Pages/Count 1/Kids[ 4 0 R ]>>endobj', '3 0 obj<</JavaScript 5 0 R >>endobj', '4 0 obj<</Type/Page/Parent 2 0 R /Contents 12 0 R>>endobj']
# results: ['%PDF-1.6', '7 0 obj', '<</Length 2307 /Filter/FlateDecode>>', 'stream', '&^:_']
# results: ['%PDF-1.0', '1 0 obj<</Type/Catalog/Pages 2 0 R /Names 3 0 R >>endobj', '2 0 obj<</Type/Pages/Count 1/Kids[ 4 0 R ]>>endobj', '3 0 obj<</JavaScript 5 0 R >>endobj', '4 0 obj<</Type/Page/Parent 2 0 R /Contents 12 0 R>>endobj']
# results: ['%PDF-1.6', '9 0 obj', '<</Filter/FlateDecode /Length 2278>>', 'stream', '$z(R']
# results: ['%PDF-1.6', '1 0 obj', '<</MediaBox [0 0 1 1] /Type/Page /Contents 3 0 R /Parent 5 0 R>>', 'endobj', '5 0 obj']
# results: ['%PDF-1.3', '1 0 obj', '/Kids [ 4 0 R ]', '/Type /Pages', '/Count 1']
# results: ['%PDF-1.6', '7 0 obj', '<</Count 1/Type/Pages/Kids[28 0 R]>>', 'endobj', '21 0 obj']
# results: ['%PDF-1.6', '3 0 obj', '<</Filter/FlateDecode /Length 1905>>', 'stream', "z]%'"]

# %% [markdown]
# # Views
# Views exemplify the true power of the workbench. They are meta workers in the broadest sense, they can call any set of workers (and other views, which are just workers of course). All of the previous notebook code focused on demonstrating the level of control and granularity you can use with workbench, here the example we're going to show for views will be for those who don't care about granularity and really just want a big 'GO' button.
#
# Reports can also be precise or general (example shows the latter):
#
#     - Customer billing View
#     - Sample volume over time View
#     - All samples that use communications calls View
#     - DO_EVERYTHING_BECAUSE_I_WANT_TO_PUNCH_GRANULARITY_IN_THE_NUTS! View
#
# So lets look at the last kind .. it's called 'view' and like many of the other workers it's 20 lines of code.
#
# But it's deceptively simple, if you think about what must be happening below... over a dozen workers are getting orchestrated and run only when it makes sense for that MIME type. So with a few  'pull' calls the recursive dependency chains are invoked; work is done if/when it's needed and the whole thing is fantastically elegant and efficient. If your mind isn't a little bit blown by what happens below then you might not be paying attention.

# %%
# This just grabs all the file_paths recursively
file_list = []
for p,d,f_list in os.walk('../test_files'):
    if 'json' in p or 'logs' in p: continue # Skipping json/logs
    file_list += [os.path.join(p, f) for f in f_list]

# %%
# Okay our database is empty, we're going to load in all the files
# which include PE files, PDFs, and ZIPs and run 'view' on them.
import pprint
results = []
for filename in file_list:
    with open(filename,'rb') as f:
        md5 = c.store_sample(os.path.basename(filename), f.read(), 'unknown')
        results.append(c.work_request('view', md5))
pprint.pprint(results[:5])
# Out:
# [{'view': {'md5': '0504b3c442166f699ce85a47b4eadd66',
#            'view_pcap_meta': {'encoding': 'binary',
#                               'file_size': 11792,
#                               'file_type': 'tcpdump capture file (little-endian) - version 2.4 (Ethernet, capture length 65535)',
#                               'filename': 'dhcp-and-dyndns.pcap',
#                               'import_time': '2014-03-13T20:08:03.288000Z',
#                               'md5': '0504b3c442166f699ce85a47b4eadd66',
#                               'mime_type': 'application/vnd.tcpdump.pcap',
#                               'type_tag': 'unknown'}}},
#  {'view': {'md5': '61d6cf490b6d3cee363f59eca547b363',
#            'view_pcap_meta': {'encoding': 'binary',
#                               'file_size': 25499,
#                               'file_type': 'tcpdump capture file (little-endian) - version 2.4 (Ethernet, capture length 65535)',
#                               'filename': 'http.pcap',
#                               'import_time': '2014-03-13T20:08:03.332000Z',
#                               'md5': '61d6cf490b6d3cee363f59eca547b363',
#                               'mime_type': 'application/vnd.tcpdump.pcap',
#                               'type_tag': 'unknown'}}},
#  {'view': {'md5': '067b3929f096768e864f6a04f04d4e54',
#            'view_pdf': {'encoding': 'binary',
#                         'file_size': 14611,
#                         'file_type': 'PDF document, version 1.6',
#                         'filename': '../test_files/pdf/bad/067b3929f096768e864f6a04f04d4e54',
#                         'import_time': '2014-03-13T20:07:57.988000Z',
#                         'md5': '067b3929f096768e864f6a04f04d4e54',
#                         'mime_type': 'application/pdf',
#                         'strings': ['%PDF-1.6',
#                                     '52 0 obj<</Length 51252212/Root 1 0 R/Info 3 0 R%/F/W[1 2 1]/Index[5 1 7 1 9 4 23 4 50 3]>>stream',
#                                     '/Filter/FlateDecode/W[1 2 1]/Index[5 1 7 1 9 4 23 4 50 3]>>stream',
#                                     'bbb0b`b```',
#                                     '310Z'],
#                         'type_tag': 'pdf'}}},
#  {'view': {'md5': '10a2b5438ba29012bae516f9873ad421',
#            'view_pdf': {'encoding': 'us-ascii',
#                         'file_size': 2057,
#                         'file_type': 'PDF document, version 1.1',
#                         'filename': '../test_files/pdf/bad/10a2b5438ba29012bae516f9873ad421',
#                         'import_time': '2014-03-13T20:07:57.994000Z',
#                         'md5': '10a2b5438ba29012bae516f9873ad421',
#                         'mime_type': 'application/pdf',
#                         'strings': ['%PDF-1.1',
#                                     '1 0 obj',
#                                     ' /Type /Catalog',
#                                     ' /Outlines 2 0 R',
#                                     ' /Pages 3 0 R'],
#                         'type_tag': 'pdf'}}},
#  {'view': {'md5': '19fae4e9d7f6ed3137b3262e243a33ea',
#            'view_pdf': {'encoding': 'binary',
#                         'file_size': 3087,
#                         'file_type': 'PDF document, version 1.3',
#                         'filename': '../test_files/pdf/bad/19fae4e9d7f6ed3137b3262e243a33ea',
#                         'import_time': '2014-03-13T20:07:58.003000Z',
#                         'md5': '19fae4e9d7f6ed3137b3262e243a33ea',
#                         'mime_type': 'application/pdf',
#                         'strings': ['%PDF-1.3',
#                                     '2 0 obj',
#                                     '/OpenAction << /JS 9 0 R /S /JavaScript >>',
#                                     '/Type /Catalog',
#                                     '/Pages 3 0 R'],
#                         'type_tag': 'pdf'}}}]

# %%
# Woot! All the magic stuff just happened and all of our collections
# per worker will have been regenerated
db.collection_names()
# Out:
# [u'system.indexes',
#  u'fs.chunks',
#  u'samples',
#  u'fs.files',
#  u'meta',
#  u'pe_features',
#  u'pe_indicators',
#  u'pe_classifier',
#  u'strings',
#  u'pcap_meta',
#  u'view_pcap_meta',
#  u'view',
#  u'view_pdf',
#  u'pe_peid',
#  u'view_pefile',
#  u'unzip',
#  u'view_zip']

# %%
# Okay so view can either aggregate results from multiple workers or they
# can subset to just want you want (webpage presentation for instance)
results = c.batch_work_request('view_customer')
pprint.pprint(results)
# Out:
# [{'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e21ac0f3',
#   'import_time': '2014-03-13T20:07:36.416000Z',
#   'length': 20480,
#   'md5': '0cb9aa6fb9c4aa3afad7a303e21ac0f3'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/033d91aae8ad29ed9fbb858179271232',
#   'import_time': '2014-03-13T20:07:38.271000Z',
#   'length': 85504,
#   'md5': '033d91aae8ad29ed9fbb858179271232'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/0e882ec9b485979ea84c7843d41ba36f',
#   'import_time': '2014-03-13T20:07:38.466000Z',
#   'length': 64512,
#   'md5': '0e882ec9b485979ea84c7843d41ba36f'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/0e8b030fb6ae48ffd29e520fc16b5641',
#   'import_time': '2014-03-13T20:07:38.642000Z',
#   'length': 81920,
#   'md5': '0e8b030fb6ae48ffd29e520fc16b5641'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/0eb9e990c521b30428a379700ec5ab3e',
#   'import_time': '2014-03-13T20:07:39.153000Z',
#   'length': 97280,
#   'md5': '0eb9e990c521b30428a379700ec5ab3e'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/127f2bade752445b3dbf2cf2ea75c201',
#   'import_time': '2014-03-13T20:07:39.464000Z',
#   'length': 66560,
#   'md5': '127f2bade752445b3dbf2cf2ea75c201'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/139385a91b9bca0833bdc1fa77e42b91',
#   'import_time': '2014-03-13T20:07:39.643000Z',
#   'length': 22510,
#   'md5': '139385a91b9bca0833bdc1fa77e42b91'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/13dcc5b4570180118eb65529b77f6d89',
#   'import_time': '2014-03-13T20:07:39.786000Z',
#   'length': 29184,
#   'md5': '13dcc5b4570180118eb65529b77f6d89'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/1cac80a2147cd8f3860547e43edcaa00',
#   'import_time': '2014-03-13T20:07:39.946000Z',
#   'length': 72704,
#   'md5': '1cac80a2147cd8f3860547e43edcaa00'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/1cea13cf888cd8ce4f869029f1dbb601',
#   'import_time': '2014-03-13T20:07:40.181000Z',
#   'length': 53248,
#   'md5': '1cea13cf888cd8ce4f869029f1dbb601'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/1d733a9e3e571ce5f5f633a0cfd3d5f0',
#   'import_time': '2014-03-13T20:07:40.338000Z',
#   'length': 48128,
#   'md5': '1d733a9e3e571ce5f5f633a0cfd3d5f0'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/2058c50de5976c67a09dfa5e0e1c7eb5',
#   'import_time': '2014-03-13T20:07:40.489000Z',
#   'length': 70661,
#   'md5': '2058c50de5976c67a09dfa5e0e1c7eb5'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/2d012cba541c22fb7250975d5ad0d065',
#   'import_time': '2014-03-13T20:07:40.651000Z',
#   'length': 47616,
#   'md5': '2d012cba541c22fb7250975d5ad0d065'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/2d015553c7388e4d78f05b24aba0819c',
#   'import_time': '2014-03-13T20:07:40.983000Z',
#   'length': 25316,
#   'md5': '2d015553c7388e4d78f05b24aba0819c'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/2d017ff228c39a0a727586b33f8168b0',
#   'import_time': '2014-03-13T20:07:41.042000Z',
#   'length': 67584,
#   'md5': '2d017ff228c39a0a727586b33f8168b0'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/2d09133abb48e1c7f3f5c8f8ced8fef4',
#   'import_time': '2014-03-13T20:07:41.179000Z',
#   'length': 81408,
#   'md5': '2d09133abb48e1c7f3f5c8f8ced8fef4'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/2d094b6c69020091b68d1bcf5d11fa4b',
#   'import_time': '2014-03-13T20:07:41.344000Z',
#   'length': 57188,
#   'md5': '2d094b6c69020091b68d1bcf5d11fa4b'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/2d095091983dd0bf6ab7c0bb6dd695f9',
#   'import_time': '2014-03-13T20:07:41.484000Z',
#   'length': 29412,
#   'md5': '2d095091983dd0bf6ab7c0bb6dd695f9'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/2d09546831b17d2cc0583362b6d312ae',
#   'import_time': '2014-03-13T20:07:41.546000Z',
#   'length': 95149,
#   'md5': '2d09546831b17d2cc0583362b6d312ae'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/2d099171876f7301c155bd775fff2b6a',
#   'import_time': '2014-03-13T20:07:41.791000Z',
#   'length': 57856,
#   'md5': '2d099171876f7301c155bd775fff2b6a'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/2d09a573b0e9d02a9fa47b16e9c01a48',
#   'import_time': '2014-03-13T20:07:41.908000Z',
#   'length': 49664,
#   'md5': '2d09a573b0e9d02a9fa47b16e9c01a48'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/2d09b5768e3617523d8afa110361919c',
#   'import_time': '2014-03-13T20:07:42.081000Z',
#   'length': 60416,
#   'md5': '2d09b5768e3617523d8afa110361919c'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/2d09b8d9852c3176259915e3509bcbd1',
#   'import_time': '2014-03-13T20:07:42.468000Z',
#   'length': 102400,
#   'md5': '2d09b8d9852c3176259915e3509bcbd1'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/2d09ca902990545fec9ac190b0338b50',
#   'import_time': '2014-03-13T20:07:42.756000Z',
#   'length': 42496,
#   'md5': '2d09ca902990545fec9ac190b0338b50'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/2d09cb38c268aa9297e5a7f27e677267',
#   'import_time': '2014-03-13T20:07:42.861000Z',
#   'length': 57856,
#   'md5': '2d09cb38c268aa9297e5a7f27e677267'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/2d09cc92bbe29d96bb3a91b350d1725f',
#   'import_time': '2014-03-13T20:07:42.991000Z',
#   'length': 78336,
#   'md5': '2d09cc92bbe29d96bb3a91b350d1725f'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/2d09e4aff42aebac87ae2fd737aba94f',
#   'import_time': '2014-03-13T20:07:43.184000Z',
#   'length': 81920,
#   'md5': '2d09e4aff42aebac87ae2fd737aba94f'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/32b24e73cfc3ac4c43f1926f8935e438',
#   'import_time': '2014-03-13T20:07:43.368000Z',
#   'length': 85504,
#   'md5': '32b24e73cfc3ac4c43f1926f8935e438'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/4ed28b6207560f127d267de639a4e1bf',
#   'import_time': '2014-03-13T20:07:43.558000Z',
#   'length': 32285,
#   'md5': '4ed28b6207560f127d267de639a4e1bf'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/505804ec7c7212a52ec85e075b91ed84',
#   'import_time': '2014-03-13T20:07:43.641000Z',
#   'length': 41472,
#   'md5': '505804ec7c7212a52ec85e075b91ed84'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/60a83c049e135cc199138c1f8861437c',
#   'import_time': '2014-03-13T20:07:43.928000Z',
#   'length': 51712,
#   'md5': '60a83c049e135cc199138c1f8861437c'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/69f9633fa6fd5dc1fd917cb435bba8ad',
#   'import_time': '2014-03-13T20:07:44.036000Z',
#   'length': 30307,
#   'md5': '69f9633fa6fd5dc1fd917cb435bba8ad'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/79f5e1af9fdb92476045989bda7515c7',
#   'import_time': '2014-03-13T20:07:44.110000Z',
#   'length': 41984,
#   'md5': '79f5e1af9fdb92476045989bda7515c7'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/7f313447b887b078215617fbed1a34a1',
#   'import_time': '2014-03-13T20:07:44.282000Z',
#   'length': 46080,
#   'md5': '7f313447b887b078215617fbed1a34a1'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/8006782bdf703e2f3fdf1d1650f45ffd',
#   'import_time': '2014-03-13T20:07:44.385000Z',
#   'length': 54755,
#   'md5': '8006782bdf703e2f3fdf1d1650f45ffd'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/86714940f491bc38c2e842e80c7f778e',
#   'import_time': '2014-03-13T20:07:44.509000Z',
#   'length': 22016,
#   'md5': '86714940f491bc38c2e842e80c7f778e'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/987bd46899b2a9493e6dec051edcb66c',
#   'import_time': '2014-03-13T20:07:44.577000Z',
#   'length': 25360,
#   'md5': '987bd46899b2a9493e6dec051edcb66c'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/9cd3d7b1b0f2aea5950cbf7d97776f2f',
#   'import_time': '2014-03-13T20:07:44.673000Z',
#   'length': 49664,
#   'md5': '9cd3d7b1b0f2aea5950cbf7d97776f2f'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/9ceccd9f32cb2ad0b140b6d15d8993b6',
#   'import_time': '2014-03-13T20:07:44.907000Z',
#   'length': 58880,
#   'md5': '9ceccd9f32cb2ad0b140b6d15d8993b6'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pe/bad/9e42ff1e6f75ae3e60b24e48367c8f26',
#   'import_time': '2014-03-13T20:07:45.088000Z',
#   'length': 51200,
#   'md5': '9e42ff1e6f75ae3e60b24e48367c8f26'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/a7b0a9067d8292b252d741e6fae17cd9',
#   'import_time': '2014-03-13T20:07:45.251000Z',
#   'length': 9953,
#   'md5': 'a7b0a9067d8292b252d741e6fae17cd9'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/afddc552b31a8f2438768c73674bf29e',
#   'import_time': '2014-03-13T20:07:45.297000Z',
#   'length': 2784,
#   'md5': 'afddc552b31a8f2438768c73674bf29e'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/b681485cb9e0cad73ee85b9274c0d3c2',
#   'import_time': '2014-03-13T20:07:45.320000Z',
#   'length': 45568,
#   'md5': 'b681485cb9e0cad73ee85b9274c0d3c2'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/bf1249a258cbcccec0f1b4ea1e9451a1',
#   'import_time': '2014-03-13T20:07:45.536000Z',
#   'length': 85504,
#   'md5': 'bf1249a258cbcccec0f1b4ea1e9451a1'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pe/bad/c8c54ac7e827056174762c68db84534f',
#   'import_time': '2014-03-13T20:07:45.699000Z',
#   'length': 37888,
#   'md5': 'c8c54ac7e827056174762c68db84534f'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/cc113aa59c04b17e7cb832fc417f104d',
#   'import_time': '2014-03-13T20:07:45.877000Z',
#   'length': 75264,
#   'md5': 'cc113aa59c04b17e7cb832fc417f104d'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/d94da41e7e809f7366971b3b50f8ef68',
#   'import_time': '2014-03-13T20:07:46.038000Z',
#   'length': 48928,
#   'md5': 'd94da41e7e809f7366971b3b50f8ef68'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/e9a6c83826deacfbc2281b6c7e401694',
#   'import_time': '2014-03-13T20:07:46.196000Z',
#   'length': 28672,
#   'md5': 'e9a6c83826deacfbc2281b6c7e401694'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pe/bad/ea5d95c96a23b21b9038f03b91955c18',
#   'import_time': '2014-03-13T20:07:46.274000Z',
#   'length': 20767,
#   'md5': 'ea5d95c96a23b21b9038f03b91955c18'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pe/bad/f6190648c2efb764ae1d73b0e9a4fd13',
#   'import_time': '2014-03-13T20:07:46.357000Z',
#   'length': 6504,
#   'md5': 'f6190648c2efb764ae1d73b0e9a4fd13'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/067b3929f096768e864f6a04f04d4e54',
#   'import_time': '2014-03-13T20:07:57.988000Z',
#   'length': 14611,
#   'md5': '067b3929f096768e864f6a04f04d4e54'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/10a2b5438ba29012bae516f9873ad421',
#   'import_time': '2014-03-13T20:07:57.994000Z',
#   'length': 2057,
#   'md5': '10a2b5438ba29012bae516f9873ad421'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/19fae4e9d7f6ed3137b3262e243a33ea',
#   'import_time': '2014-03-13T20:07:58.003000Z',
#   'length': 3087,
#   'md5': '19fae4e9d7f6ed3137b3262e243a33ea'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/1dff85e8f452908f887c39488d9f5681',
#   'import_time': '2014-03-13T20:07:58.009000Z',
#   'length': 2990,
#   'md5': '1dff85e8f452908f887c39488d9f5681'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/1e613b031d383bfd23523b38d3f03eaa',
#   'import_time': '2014-03-13T20:07:58.015000Z',
#   'length': 12745,
#   'md5': '1e613b031d383bfd23523b38d3f03eaa'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/203e51cd63c19c9992aa7879bc821cdf',
#   'import_time': '2014-03-13T20:07:58.020000Z',
#   'length': 8400,
#   'md5': '203e51cd63c19c9992aa7879bc821cdf'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/236fefdb45c0a78bd640af88b683ba24',
#   'import_time': '2014-03-13T20:07:58.029000Z',
#   'length': 2009,
#   'md5': '236fefdb45c0a78bd640af88b683ba24'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/259c05a29be71e1117bc477ec3d98866',
#   'import_time': '2014-03-13T20:07:58.035000Z',
#   'length': 12808,
#   'md5': '259c05a29be71e1117bc477ec3d98866'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/27173a0b4a5f8daae6af1f301f1095da',
#   'import_time': '2014-03-13T20:07:58.041000Z',
#   'length': 34627,
#   'md5': '27173a0b4a5f8daae6af1f301f1095da'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/29ca22d95d637d87f2384a06568e9ddf',
#   'import_time': '2014-03-13T20:07:58.047000Z',
#   'length': 6196,
#   'md5': '29ca22d95d637d87f2384a06568e9ddf'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/369614d7c422201f2d1605f4befd452d',
#   'import_time': '2014-03-13T20:07:58.059000Z',
#   'length': 72596,
#   'md5': '369614d7c422201f2d1605f4befd452d'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/3e7e6eab56bc405848d6aa1409e9359f',
#   'import_time': '2014-03-13T20:07:58.071000Z',
#   'length': 12250,
#   'md5': '3e7e6eab56bc405848d6aa1409e9359f'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/426e23531f88d2a7a90b09df9ef9cebe',
#   'import_time': '2014-03-13T20:07:58.078000Z',
#   'length': 27721,
#   'md5': '426e23531f88d2a7a90b09df9ef9cebe'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pdf/bad/47b9edb262c1734914cc148bd82fbf2c',
#   'import_time': '2014-03-13T20:07:58.086000Z',
#   'length': 10338,
#   'md5': '47b9edb262c1734914cc148bd82fbf2c'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/68ae0415f4e6c51d3c54d33921c62a05',
#   'import_time': '2014-03-13T20:07:58.099000Z',
#   'length': 27304,
#   'md5': '68ae0415f4e6c51d3c54d33921c62a05'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/73b02e77053501060747a92e9eb4adf6',
#   'import_time': '2014-03-13T20:07:58.105000Z',
#   'length': 13556,
#   'md5': '73b02e77053501060747a92e9eb4adf6'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/7cf5e503c2b92e1c154ec53808466d7c',
#   'import_time': '2014-03-13T20:07:58.114000Z',
#   'length': 57348,
#   'md5': '7cf5e503c2b92e1c154ec53808466d7c'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/8f8e12df29ae4007b9499d3fd9256048',
#   'import_time': '2014-03-13T20:07:58.123000Z',
#   'length': 30195,
#   'md5': '8f8e12df29ae4007b9499d3fd9256048'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pdf/bad/a9f147afe1c70e71c35cf8897e4edc87',
#   'import_time': '2014-03-13T20:07:58.131000Z',
#   'length': 14806,
#   'md5': 'a9f147afe1c70e71c35cf8897e4edc87'},
#  {'customer': 'Huge Inc',
#   'filename': '../test_files/pdf/bad/aa119772db9d4232d4a2c12b600ddd88',
#   'import_time': '2014-03-13T20:07:58.137000Z',
#   'length': 29841,
#   'md5': 'aa119772db9d4232d4a2c12b600ddd88'},
#  {'customer': 'Mega Corp',
#   'filename': '../test_files/pdf/bad/b30f69e91c45927bc90355298af564d7',
#   'import_time': '2014-03-13T20:07:58.143000Z',
#   'length': 14307,
#   'md5': 'b30f69e91c45927bc90355298af564d7'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/d697203216ab4d60b52ddbe0879750ea',
#   'import_time': '2014-03-13T20:07:58.150000Z',
#   'length': 45292,
#   'md5': 'd697203216ab4d60b52ddbe0879750ea'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/e1730268df98c7877d16beda98839694',
#   'import_time': '2014-03-13T20:07:58.156000Z',
#   'length': 1583,
#   'md5': 'e1730268df98c7877d16beda98839694'},
#  {'customer': 'BearTron',
#   'filename': '../test_files/pdf/bad/ecdb64ce7d08fd03b07c56f9470f90d9',
#   'import_time': '2014-03-13T20:07:58.167000Z',
#   'length': 12272,
#   'md5': 'ecdb64ce7d08fd03b07c56f9470f90d9'},
#  {'customer': 'Dorseys Mom',
#   'filename': '../test_files/pdf/bad/f986630baf582799b045b82aa0b789ad',
#   'import_time': '2014-03-13T20:07:58.174000Z',
#   'length': 12055,
#   'md5': 'f986630baf582799b045b82aa0b789ad'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'dhcp-and-dyndns.pcap',
#   'import_time': '2014-03-13T20:08:03.288000Z',
#   'length': 11792,
#   'md5': '0504b3c442166f699ce85a47b4eadd66'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'http.pcap',
#   'import_time': '2014-03-13T20:08:03.332000Z',
#   'length': 25499,
#   'md5': '61d6cf490b6d3cee363f59eca547b363'},
#  {'customer': 'Huge Inc',
#   'filename': '09c9d9aeb00037bdfb468fe46a8e9688',
#   'import_time': '2014-03-13T20:08:03.903000Z',
#   'length': 26504,
#   'md5': '09c9d9aeb00037bdfb468fe46a8e9688'},
#  {'customer': 'Mega Corp',
#   'filename': '0f86e40a2da406862c49689d2847384b',
#   'import_time': '2014-03-13T20:08:03.929000Z',
#   'length': 59298,
#   'md5': '0f86e40a2da406862c49689d2847384b'},
#  {'customer': 'Mega Corp',
#   'filename': '2095056c96b68b787288c865485ab355',
#   'import_time': '2014-03-13T20:08:03.962000Z',
#   'length': 24200,
#   'md5': '2095056c96b68b787288c865485ab355'},
#  {'customer': 'Mega Corp',
#   'filename': '3496927b377ab840803fa210ab7116a8',
#   'import_time': '2014-03-13T20:08:03.995000Z',
#   'length': 26621,
#   'md5': '3496927b377ab840803fa210ab7116a8'},
#  {'customer': 'Dorseys Mom',
#   'filename': '3a30e519ae81b995a92545205c6018cc',
#   'import_time': '2014-03-13T20:08:04.035000Z',
#   'length': 12200,
#   'md5': '3a30e519ae81b995a92545205c6018cc'},
#  {'customer': 'BearTron',
#   'filename': '3b48469a80749ca4cd35e5569a28b110',
#   'import_time': '2014-03-13T20:08:04.059000Z',
#   'length': 4778,
#   'md5': '3b48469a80749ca4cd35e5569a28b110'},
#  {'customer': 'BearTron',
#   'filename': '3f943980cad294d99a5a529d41713593',
#   'import_time': '2014-03-13T20:08:04.086000Z',
#   'length': 20598,
#   'md5': '3f943980cad294d99a5a529d41713593'},
#  {'customer': 'Dorseys Mom',
#   'filename': '4a39e8d9647fe4b498d9949ac8ca4a43',
#   'import_time': '2014-03-13T20:08:04.119000Z',
#   'length': 17228,
#   'md5': '4a39e8d9647fe4b498d9949ac8ca4a43'},
#  {'customer': 'BearTron',
#   'filename': '4bc0aff0651a0b18fb9c6a80bd01b1f3',
#   'import_time': '2014-03-13T20:08:04.147000Z',
#   'length': 71235,
#   'md5': '4bc0aff0651a0b18fb9c6a80bd01b1f3'},
#  {'customer': 'Dorseys Mom',
#   'filename': '4fcc2d8c1c1b80b7b2bb6351290d8c88',
#   'import_time': '2014-03-13T20:08:04.187000Z',
#   'length': 63065,
#   'md5': '4fcc2d8c1c1b80b7b2bb6351290d8c88'},
#  {'customer': 'Mega Corp',
#   'filename': '507eb1a161f7eff568c27f19bc7ec596',
#   'import_time': '2014-03-13T20:08:04.233000Z',
#   'length': 51803,
#   'md5': '507eb1a161f7eff568c27f19bc7ec596'},
#  {'customer': 'Mega Corp',
#   'filename': '5d1c4b1575318f1d15f344e2962d0078',
#   'import_time': '2014-03-13T20:08:04.281000Z',
#   'length': 38458,
#   'md5': '5d1c4b1575318f1d15f344e2962d0078'},
#  {'customer': 'BearTron',
#   'filename': '5fc37d0bd05103ab4808458395c4e70f',
#   'import_time': '2014-03-13T20:08:04.320000Z',
#   'length': 56501,
#   'md5': '5fc37d0bd05103ab4808458395c4e70f'},
#  {'customer': 'Mega Corp',
#   'filename': '644ccf278abbbe84358857ce770940dd',
#   'import_time': '2014-03-13T20:08:04.359000Z',
#   'length': 11571,
#   'md5': '644ccf278abbbe84358857ce770940dd'},
#  {'customer': 'Mega Corp',
#   'filename': '6e4ce29d57c01be35f907354bcd4a4f3',
#   'import_time': '2014-03-13T20:08:04.392000Z',
#   'length': 57757,
#   'md5': '6e4ce29d57c01be35f907354bcd4a4f3'},
#  {'customer': 'Mega Corp',
#   'filename': '8747e193b8381818b57ccb2bda159a85',
#   'import_time': '2014-03-13T20:08:04.417000Z',
#   'length': 12165,
#   'md5': '8747e193b8381818b57ccb2bda159a85'},
#  {'customer': 'Mega Corp',
#   'filename': '8eaab87c0ff58665f8cb6785b3d3b233',
#   'import_time': '2014-03-13T20:08:04.441000Z',
#   'length': 59305,
#   'md5': '8eaab87c0ff58665f8cb6785b3d3b233'},
#  {'customer': 'Huge Inc',
#   'filename': '98a896a6c62583eed05c59eef1354497',
#   'import_time': '2014-03-13T20:08:04.470000Z',
#   'length': 68651,
#   'md5': '98a896a6c62583eed05c59eef1354497'},
#  {'customer': 'Huge Inc',
#   'filename': '9f897638907e7efcc70f80b9a9cb745a',
#   'import_time': '2014-03-13T20:08:04.498000Z',
#   'length': 24276,
#   'md5': '9f897638907e7efcc70f80b9a9cb745a'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'a319d690068814b45649a4134688a245',
#   'import_time': '2014-03-13T20:08:04.525000Z',
#   'length': 59275,
#   'md5': 'a319d690068814b45649a4134688a245'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'b93bbef4869dbae9f1d0e023fedb7681',
#   'import_time': '2014-03-13T20:08:04.552000Z',
#   'length': 78430,
#   'md5': 'b93bbef4869dbae9f1d0e023fedb7681'},
#  {'customer': 'Mega Corp',
#   'filename': 'de1f1fefd6a8d717a042884641dd1086',
#   'import_time': '2014-03-13T20:08:04.587000Z',
#   'length': 27650,
#   'md5': 'de1f1fefd6a8d717a042884641dd1086'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'e9dd99d4f641f4be3f2aa82d5248a6af',
#   'import_time': '2014-03-13T20:08:04.612000Z',
#   'length': 59307,
#   'md5': 'e9dd99d4f641f4be3f2aa82d5248a6af'},
#  {'customer': 'BearTron',
#   'filename': 'ec79923155af9a21f57b76d3d6f15dc5',
#   'import_time': '2014-03-13T20:08:04.650000Z',
#   'length': 5305,
#   'md5': 'ec79923155af9a21f57b76d3d6f15dc5'},
#  {'customer': 'Mega Corp',
#   'filename': 'f1eb8996a70da3aa4d99d3d8e3a907dc',
#   'import_time': '2014-03-13T20:08:04.689000Z',
#   'length': 85857,
#   'md5': 'f1eb8996a70da3aa4d99d3d8e3a907dc'},
#  {'customer': 'Dorseys Mom',
#   'filename': '090a189f4eeb3c0b76e97acdb1a71c92',
#   'import_time': '2014-03-13T20:08:29.488000Z',
#   'length': 69144,
#   'md5': '090a189f4eeb3c0b76e97acdb1a71c92'},
#  {'customer': 'Huge Inc',
#   'filename': '093dee8d97fd9d35884ed52179b3d142',
#   'import_time': '2014-03-13T20:08:30.385000Z',
#   'length': 54080,
#   'md5': '093dee8d97fd9d35884ed52179b3d142'},
#  {'customer': 'Dorseys Mom',
#   'filename': '0dd74786d22edff0ce5b8e1b1e398618',
#   'import_time': '2014-03-13T20:08:31.171000Z',
#   'length': 18544,
#   'md5': '0dd74786d22edff0ce5b8e1b1e398618'},
#  {'customer': 'Mega Corp',
#   'filename': '10328f92e7ec8735ea7846bf2c8254c2',
#   'import_time': '2014-03-13T20:08:31.776000Z',
#   'length': 41472,
#   'md5': '10328f92e7ec8735ea7846bf2c8254c2'},
#  {'customer': 'Mega Corp',
#   'filename': '12fd4ef8f2cbbf98e0a5ced88258ddf3',
#   'import_time': '2014-03-13T20:08:32.327000Z',
#   'length': 17816,
#   'md5': '12fd4ef8f2cbbf98e0a5ced88258ddf3'},
#  {'customer': 'Mega Corp',
#   'filename': '2352ab5f9f8f097bf9d41d5a4718a041',
#   'import_time': '2014-03-13T20:08:32.953000Z'
# ,
#   'length': 86016,
#   'md5': '2352ab5f9f8f097bf9d41d5a4718a041'},
#  {'customer': 'Mega Corp',
#   'filename': '23c2fcaa50c4f80f7d1b8a0771d45328',
#   'import_time': '2014-03-13T20:08:33.832000Z',
#   'length': 59720,
#   'md5': '23c2fcaa50c4f80f7d1b8a0771d45328'},
#  {'customer': 'Dorseys Mom',
#   'filename': '2459a629ace148286360b860442221a2',
#   'import_time': '2014-03-13T20:08:34.667000Z',
#   'length': 77824,
#   'md5': '2459a629ace148286360b860442221a2'},
#  {'customer': 'Dorseys Mom',
#   'filename': '29198eb44d87d25cb81f89c40c8a5999',
#   'import_time': '2014-03-13T20:08:35.453000Z',
#   'length': 41472,
#   'md5': '29198eb44d87d25cb81f89c40c8a5999'},
#  {'customer': 'Huge Inc',
#   'filename': '2cbfc3993bd5134d58d12668f21d91da',
#   'import_time': '2014-03-13T20:08:36.070000Z',
#   'length': 82464,
#   'md5': '2cbfc3993bd5134d58d12668f21d91da'},
#  {'customer': 'Mega Corp',
#   'filename': '2da49f579107981542cf920f8b70648a',
#   'import_time': '2014-03-13T20:08:36.856000Z',
#   'length': 77136,
#   'md5': '2da49f579107981542cf920f8b70648a'},
#  {'customer': 'BearTron',
#   'filename': '30e3850f303eae5c364782ea78579cc9',
#   'import_time': '2014-03-13T20:08:37.660000Z',
#   'length': 55624,
#   'md5': '30e3850f303eae5c364782ea78579cc9'},
#  {'customer': 'Dorseys Mom',
#   'filename': '3c8ae626058a59e7be93adbe3a5a1e92',
#   'import_time': '2014-03-13T20:08:38.450000Z',
#   'length': 23408,
#   'md5': '3c8ae626058a59e7be93adbe3a5a1e92'},
#  {'customer': 'Dorseys Mom',
#   'filename': '41636f77ad6d9a396ea34e4786b96f2b',
#   'import_time': '2014-03-13T20:08:39.017000Z',
#   'length': 21504,
#   'md5': '41636f77ad6d9a396ea34e4786b96f2b'},
#  {'customer': 'Dorseys Mom',
#   'filename': '425e22d9f5c01616afc92987791b19e9',
#   'import_time': '2014-03-13T20:08:39.681000Z',
#   'length': 31552,
#   'md5': '425e22d9f5c01616afc92987791b19e9'},
#  {'customer': 'BearTron',
#   'filename': '47833576f0bee0ad7b45109982b769bd',
#   'import_time': '2014-03-13T20:08:40.399000Z',
#   'length': 59720,
#   'md5': '47833576f0bee0ad7b45109982b769bd'},
#  {'customer': 'Dorseys Mom',
#   'filename': '4be7ec02133544cde7a580875e130208',
#   'import_time': '2014-03-13T20:08:41.266000Z',
#   'length': 50344,
#   'md5': '4be7ec02133544cde7a580875e130208'},
#  {'customer': 'BearTron',
#   'filename': '4d41d30e2fab3307967c7a0b045dc874',
#   'import_time': '2014-03-13T20:08:42.022000Z',
#   'length': 50344,
#   'md5': '4d41d30e2fab3307967c7a0b045dc874'},
#  {'customer': 'BearTron',
#   'filename': '4d71227301dd8d09097b9e4cc6527e5a',
#   'import_time': '2014-03-13T20:08:42.821000Z',
#   'length': 30720,
#   'md5': '4d71227301dd8d09097b9e4cc6527e5a'},
#  {'customer': 'Dorseys Mom',
#   'filename': '52744454c74fac9fcc8f5efb6418c9b4',
#   'import_time': '2014-03-13T20:08:43.673000Z',
#   'length': 46392,
#   'md5': '52744454c74fac9fcc8f5efb6418c9b4'},
#  {'customer': 'Dorseys Mom',
#   'filename': '52d60e642263719b37f1e4a785e676eb',
#   'import_time': '2014-03-13T20:08:44.509000Z',
#   'length': 23808,
#   'md5': '52d60e642263719b37f1e4a785e676eb'},
#  {'customer': 'Dorseys Mom',
#   'filename': '550388c7aecde4bf6fae9f77755d54de',
#   'import_time': '2014-03-13T20:08:45.044000Z',
#   'length': 84368,
#   'md5': '550388c7aecde4bf6fae9f77755d54de'},
#  {'customer': 'Dorseys Mom',
#   'filename': '5883d86f8c22b1e5f78627e4af19b234',
#   'import_time': '2014-03-13T20:08:45.901000Z',
#   'length': 59720,
#   'md5': '5883d86f8c22b1e5f78627e4af19b234'},
#  {'customer': 'Dorseys Mom',
#   'filename': '58a29227283acf2a0a9f127f0176af73',
#   'import_time': '2014-03-13T20:08:46.835000Z',
#   'length': 96256,
#   'md5': '58a29227283acf2a0a9f127f0176af73'},
#  {'customer': 'BearTron',
#   'filename': '5caea70e05a942e9ee9e02d178a28b1a',
#   'import_time': '2014-03-13T20:08:47.651000Z',
#   'length': 46392,
#   'md5': '5caea70e05a942e9ee9e02d178a28b1a'},
#  {'customer': 'Dorseys Mom',
#   'filename': '66a93f2e5d7bad7b2c5810f726563d49',
#   'import_time': '2014-03-13T20:08:48.546000Z',
#   'length': 87040,
#   'md5': '66a93f2e5d7bad7b2c5810f726563d49'},
#  {'customer': 'BearTron',
#   'filename': '73b459178a48657d5e92c41ec1fdd716',
#   'import_time': '2014-03-13T20:08:49.503000Z',
#   'length': 28480,
#   'md5': '73b459178a48657d5e92c41ec1fdd716'},
#  {'customer': 'Mega Corp',
#   'filename': '74855d03ee3999e56b785a33b956245d',
#   'import_time': '2014-03-13T20:08:50.180000Z',
#   'length': 87296,
#   'md5': '74855d03ee3999e56b785a33b956245d'},
#  {'customer': 'Mega Corp',
#   'filename': '7675e15d1b2180745e4da4d26aad7385',
#   'import_time': '2014-03-13T20:08:50.986000Z',
#   'length': 23808,
#   'md5': '7675e15d1b2180745e4da4d26aad7385'},
#  {'customer': 'Dorseys Mom',
#   'filename': '76d614e35d6727ab3a72880a36af91d1',
#   'import_time': '2014-03-13T20:08:51.663000Z',
#   'length': 78848,
#   'md5': '76d614e35d6727ab3a72880a36af91d1'},
#  {'customer': 'Mega Corp',
#   'filename': '7c20f04b00f9bf02fc5ea1218b24997d',
#   'import_time': '2014-03-13T20:08:52.982000Z',
#   'length': 64200,
#   'md5': '7c20f04b00f9bf02fc5ea1218b24997d'},
#  {'customer': 'Huge Inc',
#   'filename': '8003518cf919df3475531124b327ceb8',
#   'import_time': '2014-03-13T20:08:53.908000Z',
#   'length': 96968,
#   'md5': '8003518cf919df3475531124b327ceb8'},
#  {'customer': 'Dorseys Mom',
#   'filename': '803b370865d907ea21dc0c2b6a8936b5',
#   'import_time': '2014-03-13T20:08:54.722000Z',
#   'length': 22016,
#   'md5': '803b370865d907ea21dc0c2b6a8936b5'},
#  {'customer': 'Huge Inc',
#   'filename': '85e7f4b0a07a16f21c23b5b467e02ddc',
#   'import_time': '2014-03-13T20:08:55.447000Z',
#   'length': 27912,
#   'md5': '85e7f4b0a07a16f21c23b5b467e02ddc'},
#  {'customer': 'BearTron',
#   'filename': '9330941c8f6df417f6dbbe998db6687e',
#   'import_time': '2014-03-13T20:08:56.128000Z',
#   'length': 46808,
#   'md5': '9330941c8f6df417f6dbbe998db6687e'},
#  {'customer': 'Dorseys Mom',
#   'filename': '9333096b59dad0c4294749755963dba7',
#   'import_time': '2014-03-13T20:08:56.986000Z',
#   'length': 64544,
#   'md5': '9333096b59dad0c4294749755963dba7'},
#  {'customer': 'BearTron',
#   'filename': 'a3661a61f7e7b7d37e6d037ed747e7ef',
#   'import_time': '2014-03-13T20:08:57.922000Z',
#   'length': 45376,
#   'md5': 'a3661a61f7e7b7d37e6d037ed747e7ef'},
#  {'customer': 'Mega Corp',
#   'filename': 'a6abdcf2d0de0f1a9d429b0b5ae8b915',
#   'import_time': '2014-03-13T20:08:58.769000Z',
#   'length': 73728,
#   'md5': 'a6abdcf2d0de0f1a9d429b0b5ae8b915'},
#  {'customer': 'Mega Corp',
#   'filename': 'abdfc692d9fe43e2ba8fe6cb5a8cb95a',
#   'import_time': '2014-03-13T20:08:59.415000Z',
#   'length': 13312,
#   'md5': 'abdfc692d9fe43e2ba8fe6cb5a8cb95a'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'b362181ed3771dc03b4141927c80f801',
#   'import_time': '2014-03-13T20:09:00.064000Z',
#   'length': 65432,
#   'md5': 'b362181ed3771dc03b4141927c80f801'},
#  {'customer': 'Huge Inc',
#   'filename': 'be1dae43dfbca94fb6b4157c1b16923e',
#   'import_time': '2014-03-13T20:09:00.910000Z',
#   'length': 49664,
#   'md5': 'be1dae43dfbca94fb6b4157c1b16923e'},
#  {'customer': 'Huge Inc',
#   'filename': 'c6b6a394c597dfca84a2e98a9c0dc58f',
#   'import_time': '2014-03-13T20:09:01.831000Z',
#   'length': 35136,
#   'md5': 'c6b6a394c597dfca84a2e98a9c0dc58f'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'd53024c1355615b82dd1526b63623e61',
#   'import_time': '2014-03-13T20:09:02.486000Z',
#   'length': 88256,
#   'md5': 'd53024c1355615b82dd1526b63623e61'},
#  {'customer': 'Dorseys Mom',
#   'filename': 'd74884939d53612fd84ac82c59ccfe27',
#   'import_time': '2014-03-13T20:09:03.338000Z',
#   'length': 50344,
#   'md5': 'd74884939d53612fd84ac82c59ccfe27'},
#  {'customer': 'BearTron',
#   'filename': 'dd79a6b15c2f28de98df4852aaf6b13b',
#   'import_time': '2014-03-13T20:09:04.101000Z',
#   'length': 21720,
#   'md5': 'dd79a6b15c2f28de98df4852aaf6b13b'},
#  {'customer': 'Mega Corp',
#   'filename': 'e0b173f23d873286169995d66b9e3cdf',
#   'import_time': '2014-03-13T20:09:04.663000Z',
#   'length': 18544,
#   'md5': 'e0b173f23d873286169995d66b9e3cdf'},
#  {'customer': 'Mega Corp',
#   'filename': 'e2dc2eb9e034a261d1b8f0078813cd3f',
#   'import_time': '2014-03-13T20:09:05.272000Z',
#   'length': 55592,
#   'md5': 'e2dc2eb9e034a261d1b8f0078813cd3f'},
#  {'customer': 'Huge Inc',
#   'filename': 'e87f31116298d4d4839e50fce87b9f6f',
#   'import_time': '2014-03-13T20:09:06.020000Z',
#   'length': 46392,
#   'md5': 'e87f31116298d4d4839e50fce87b9f6f'},
#  {'customer': 'Huge Inc',
#   'filename': 'e9559d481589ac249f97b77169c09394',
#   'import_time': '2014-03-13T20:09:06.741000Z',
#   'length': 36864,
#   'md5': 'e9559d481589ac249f97b77169c09394'},
#  {'customer': 'BearTron',
#   'filename': 'ee7c82b0d69f038245cecbce9ec45a9a',
#   'import_time': '2014-03-13T20:09:07.439000Z',
#   'length': 17760,
#   'md5': 'ee7c82b0d69f038245cecbce9ec45a9a'},
#  {'customer': 'BearTron',
#   'filename': 'bad.zip',
#   'import_time': '2014-03-13T20:09:08.089000Z',
#   'length': 77993,
#   'md5': '5d8ba23c49ad903e7281ddea6cece67a'},
#  {'customer': 'BearTron',
#   'filename': 'good.zip',
#   'import_time': '2014-03-13T20:09:08.122000Z',
#   'length': 73275,
#   'md5': '64f4c5b055251a6ea934bc98db5f1032'}]

# %%
# At this granularity it opens up a new world
import pandas as pd
df = pd.DataFrame.from_records(results)
df.head()
# Out:
#       customer                                           filename  \
# 0    Mega Corp  ../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e...
# 1  Dorseys Mom  ../test_files/pe/bad/033d91aae8ad29ed9fbb85817...
# 2  Dorseys Mom  ../test_files/pe/bad/0e882ec9b485979ea84c7843d...
# 3     BearTron  ../test_files/pe/bad/0e8b030fb6ae48ffd29e520fc...
# 4  Dorseys Mom  ../test_files/pe/bad/0eb9e990c521b30428a379700...
#
#                    import_time  length                               md5
# 0  2014-03-13T20:07:36.416000Z   20480  0cb9aa6fb9c4aa3afad7a303e21ac0f3
# 1  2014-03-13T20:07:38.271000Z   85504  033d91aae8ad29ed9fbb858179271232
# 2  2014-03-13T20:07:38.466000Z   64512  0e882ec9b485979ea84c7843d41ba36f
# 3  2014-03-13T20:07:38.642000Z   81920  0e8b030fb6ae48ffd29e520fc16b5641
# 4  2014-03-13T20:07:39.153000Z   97280  0eb9e990c521b30428a379700ec5ab3e
#
# [5 rows x 5 columns]

# %%
# Plotting defaults
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.size'] = 12.0
plt.rcParams['figure.figsize'] = 18.0, 8.0

# %%
# Plot file length box plots based on customer
df.boxplot('length','customer')
plt.xlabel('Customer')
plt.ylabel('File Size')

# %%
# Okay now lets do some plots on the file meta-data
results = c.batch_work_request('meta_deep')

# %%
df_meta = pd.DataFrame.from_records(results)
df_meta.head(10)
# Out:
#   encoding   entropy  file_size  \
# 0   binary  2.440069      20480
# 1   binary  7.894680      85504
# 2   binary  5.125292      64512
# 3   binary  6.303055      81920
# 4   binary  7.593283      97280
# 5   binary  5.819876      66560
# 6   binary  5.464102      22510
# 7   binary  5.934043      29184
# 8   binary  6.862947      72704
# 9   binary  6.126764      53248
#
#                                            file_type  \
# 0  PE32 executable (GUI) Intel 80386, for MS Windows
# 1  PE32 executable (GUI) Intel 80386, for MS Windows
# 2  PE32 executable (GUI) Intel 80386, for MS Windows
# 3  PE32 executable (GUI) Intel 80386, for MS Windows
# 4  PE32 executable (GUI) Intel 80386, for MS Windows
# 5  PE32 executable (GUI) Intel 80386, for MS Windows
# 6  PE32 executable (GUI) Intel 80386, for MS Windows
# 7  PE32 executable (GUI) Intel 80386, for MS Windows
# 8  PE32 executable (GUI) Intel 80386, for MS Windows
# 9  PE32 executable (console) Intel 80386, for MS ...
#
#                                             filename  \
# 0  ../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e...
# 1  ../test_files/pe/bad/033d91aae8ad29ed9fbb85817...
# 2  ../test_files/pe/bad/0e882ec9b485979ea84c7843d...
# 3  ../test_files/pe/bad/0e8b030fb6ae48ffd29e520fc...
# 4  ../test_files/pe/bad/0eb9e990c521b30428a379700...
# 5  ../test_files/pe/bad/127f2bade752445b3dbf2cf2e...
# 6  ../test_files/pe/bad/139385a91b9bca0833bdc1fa7...
# 7  ../test_files/pe/bad/13dcc5b4570180118eb65529b...
# 8  ../test_files/pe/bad/1cac80a2147cd8f3860547e43...
# 9  ../test_files/pe/bad/1cea13cf888cd8ce4f869029f...
#
#                    import_time                               md5  \
# 0  2014-03-13T20:07:36.416000Z  0cb9aa6fb9c4aa3afad7a303e21ac0f3
# 1  2014-03-13T20:07:38.271000Z  033d91aae8ad29ed9fbb858179271232
# 2  2014-03-13T20:07:38.466000Z  0e882ec9b485979ea84c7843d41ba36f
# 3  2014-03-13T20:07:38.642000Z  0e8b030fb6ae48ffd29e520fc16b5641
# 4  2014-03-13T20:07:39.153000Z  0eb9e990c521b30428a379700ec5ab3e
# 5  2014-03-13T20:07:39.464000Z  127f2bade752445b3dbf2cf2ea75c201
# 6  2014-03-13T20:07:39.643000Z  139385a91b9bca0833bdc1fa77e42b91
# 7  2014-03-13T20:07:39.786000Z  13dcc5b4570180118eb65529b77f6d89
# 8  2014-03-13T20:07:39.946000Z  1cac80a2147cd8f3860547e43edcaa00
# 9  2014-03-13T20:07:40.181000Z  1cea13cf888cd8ce4f869029f1dbb601
#
#                mime_type                                      sha1  \
# 0  application/x-dosexec  96e85768a12b2f319f2a4f0c048460e1b73aa573
# 1  application/x-dosexec  83ab10907b254752f312c89125957f10d35cb9d4
# 2  application/x-dosexec  12fb0a1b7d9c2b2a41f4da9ce5bbfb140fb16939
# 3  application/x-dosexec  82d57b8302b7497b2f6943f18e2d2687b9b0f5eb
# 4  application/x-dosexec  b778fc55f0538de865d4853099a3faa0b29f311d
# 5  application/x-dosexec  8f85c1d422cf671752f670132755e582b0f0df91
# 6  application/x-dosexec  8a3cdd2ba8fbc340c3e7d8846557ec0b9c67ea1c
# 7  application/x-dosexec  a4eda90984f26e9fdbe2a7e46989b5c6fa20ba8a
# 8  application/x-dosexec  a6074b457d6d034aa42c9578ccb25e6cd0ce55fd
# 9  application/x-dosexec  24eaad952e7b082c43c0c1d5491a11b15b3c9ddd
#
#                                               sha256  \
# 0  4ecf79302ba0439f62e15d0526a297975e6bb32ea25c8c...
# 1  eb107c004e6e1bbd3b32ad7961661bbe28a577b0cb5dac...
# 2  616cf9e729c883d979212eb55178b7aac80dd9f58cb449...
# 3  feaf72bdad035e198d297bfb0b8d891645f1dacd78f0db...
# 4  dc5e8176a5f012ebdb4835f9b570a12c045d059f6f5bdc...
# 5  39406e20428d6b4cf4d3bfc808f25054c3b3a020b3799a...
# 6  b059cc3092e47f6ca63dff2bf3b3d5e08bf49d1bc50255...
# 7  07e830bb2fd15863923d3765dfc16f119de4742aada2e4...
# 8  28f3dd5018da2401746b799c7edf5cb9d6ea6806086218...
# 9  7376ffef9241bacba97d5dfdcb342728b00e2b59baecd2...
#
#                                               ssdeep type_tag
# 0  192:a8jJIFYrq9ATskBTp2jLDL3P1oynldvSo71nF:oFpN...       pe
# 1  1536:h6+LbfPbI5dzmJu9Tgj5aOItvEqRCHW9pjVrs2ryr...       pe
# 2  768:5HyLMqtEM1Htz8kDmP9l+nZZYp41oj7EZmJxl/N9j6...       pe
# 3  1536:1uNqjqzs1hQHhInEeJMzcmGqyF7Jwe9pvUo+5TDU4...       pe
# 4  1536:KcE4iMgXjTJpdGaaJG6Mhawv7r9ZaobsLBq+h5ttB...       pe
# 5  1536:wc9nwQYsQtdFwFQ8bjaQobU52FWAltktg6y+v:MQY...       pe
# 6  384:BYErZeuq+jw3ESfIwh5FR8ufHenEpH0zn6cLZ3j1:9...       pe
# 7  384:ckRyL5UF+gVuh9lAOefV+aPd34wwIaSV79Jsl+RDnO...       pe
# 8  1536:Fm6yECw0qjW9SRnkgFfln/8F8J4kMtNYJHnUlc:FT...       pe
# 9  768:hUuMWpab5i+rQylxt2zeqAHVXi7/UoucttjyjvKkwp...       pe
#
# [10 rows x 12 columns]

# %%
# Plot entropy box plots based on mime-type
df_meta.boxplot('entropy','mime_type')
plt.xlabel('Mime Type')
plt.ylabel('Entropy')

# %%
# Hee, Hee now merge the two dataframes together to plot customer submissions based on mime-type
df_combined = df_meta.merge(df, on='md5')
df_combined.head()
# Out:
#   encoding   entropy  file_size  \
# 0   binary  2.440069      20480
# 1   binary  7.894680      85504
# 2   binary  5.125292      64512
# 3   binary  6.303055      81920
# 4   binary  7.593283      97280
#
#                                            file_type  \
# 0  PE32 executable (GUI) Intel 80386, for MS Windows
# 1  PE32 executable (GUI) Intel 80386, for MS Windows
# 2  PE32 executable (GUI) Intel 80386, for MS Windows
# 3  PE32 executable (GUI) Intel 80386, for MS Windows
# 4  PE32 executable (GUI) Intel 80386, for MS Windows
#
#                                           filename_x  \
# 0  ../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e...
# 1  ../test_files/pe/bad/033d91aae8ad29ed9fbb85817...
# 2  ../test_files/pe/bad/0e882ec9b485979ea84c7843d...
# 3  ../test_files/pe/bad/0e8b030fb6ae48ffd29e520fc...
# 4  ../test_files/pe/bad/0eb9e990c521b30428a379700...
#
#                  import_time_x                               md5  \
# 0  2014-03-13T20:07:36.416000Z  0cb9aa6fb9c4aa3afad7a303e21ac0f3
# 1  2014-03-13T20:07:38.271000Z  033d91aae8ad29ed9fbb858179271232
# 2  2014-03-13T20:07:38.466000Z  0e882ec9b485979ea84c7843d41ba36f
# 3  2014-03-13T20:07:38.642000Z  0e8b030fb6ae48ffd29e520fc16b5641
# 4  2014-03-13T20:07:39.153000Z  0eb9e990c521b30428a379700ec5ab3e
#
#                mime_type                                      sha1  \
# 0  application/x-dosexec  96e85768a12b2f319f2a4f0c048460e1b73aa573
# 1  application/x-dosexec  83ab10907b254752f312c89125957f10d35cb9d4
# 2  application/x-dosexec  12fb0a1b7d9c2b2a41f4da9ce5bbfb140fb16939
# 3  application/x-dosexec  82d57b8302b7497b2f6943f18e2d2687b9b0f5eb
# 4  application/x-dosexec  b778fc55f0538de865d4853099a3faa0b29f311d
#
#                                               sha256  \
# 0  4ecf79302ba0439f62e15d0526a297975e6bb32ea25c8c...
# 1  eb107c004e6e1bbd3b32ad7961661bbe28a577b0cb5dac...
# 2  616cf9e729c883d979212eb55178b7aac80dd9f58cb449...
# 3  feaf72bdad035e198d297bfb0b8d891645f1dacd78f0db...
# 4  dc5e8176a5f012ebdb4835f9b570a12c045d059f6f5bdc...
#
#                                               ssdeep type_tag     customer  \
# 0  192:a8jJIFYrq9ATskBTp2jLDL3P1oynldvSo71nF:oFpN...       pe    Mega Corp
# 1  1536:h6+LbfPbI5dzmJu9Tgj5aOItvEqRCHW9pjVrs2ryr...       pe  Dorseys Mom
# 2  768:5HyLMqtEM1Htz8kDmP9l+nZZYp41oj7EZmJxl/N9j6...       pe  Dorseys Mom
# 3  1536:1uNqjqzs1hQHhInEeJMzcmGqyF7Jwe9pvUo+5TDU4...       pe     BearTron
# 4  1536:KcE4iMgXjTJpdGaaJG6Mhawv7r9ZaobsLBq+h5ttB...       pe  Dorseys Mom
#
#                                           filename_y  \
# 0  ../test_files/pe/bad/0cb9aa6fb9c4aa3afad7a303e...
# 1  ../test_files/pe/bad/033d91aae8ad29ed9fbb85817...
# 2  ../test_files/pe/bad/0e882ec9b485979ea84c7843d...
# 3  ../test_files/pe/bad/0e8b030fb6ae48ffd29e520fc...
# 4  ../test_files/pe/bad/0eb9e990c521b30428a379700...
#
#                  import_time_y  length
# 0  2014-03-13T20:07:36.416000Z   20480
# 1  2014-03-13T20:07:38.271000Z   85504
# 2  2014-03-13T20:07:38.466000Z   64512
# 3  2014-03-13T20:07:38.642000Z   81920
# 4  2014-03-13T20:07:39.153000Z   97280
#
# [5 rows x 16 columns]

# %%
group_df = df_combined[['customer','mime_type']]
group_df['submissions'] = 1
group_df = group_df.groupby(['customer','mime_type']).sum().unstack()
group_df.head()
# Out:
#                  submissions                                \
# mime_type    application/pdf  application/vnd.tcpdump.pcap
# customer
# BearTron                  12                           NaN
# Dorseys Mom               14                             2
# Huge Inc                  10                           NaN
# Mega Corp                 14                           NaN
#
#
# mime_type    application/x-dosexec  application/zip
# customer
# BearTron                        25                2
# Dorseys Mom                     28              NaN
# Huge Inc                        22              NaN
# Mega Corp                       25              NaN
#
# [4 rows x 4 columns]

# %%
# Plot entropy box plots based on mime-type
group_df['submissions'].plot(kind='bar', stacked=True)
plt.xlabel('Customer')
plt.ylabel('Submissions')
